# %% [markdown]
# # Extract and crop the interpreter

# %%
import os
import sys

import numpy as np

notebook_dir = os.getcwd()
project_root = os.path.abspath(os.path.join(notebook_dir, '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %load_ext autoreload
# %autoreload 2

ROOT_DIR = 'scraped'


# Interpreter box
def crop_interpreter(img: np.ndarray):
    h, w = img.shape[:2]

    if h == 720:
        X, Y = 952, 347
        W, H = 300, 322
    elif h == 432:
        X, Y = 571, 208
        W, H = 180, 193
    else:
        raise ValueError('Height not supported')

    return img[Y : Y + H, X : X + W]

# %% [markdown]
# ## Get frame indexes between which the interpreter is present

# %%
import json
import os
from cv2 import VideoCapture
import cv2
import face_recognition

from utils.video import get_vid_metadata, get_frame


known_faces = []
known_people = []
for file_name in os.listdir('known_people'):
    img = face_recognition.load_image_file(os.path.join('known_people', file_name))
    enc = face_recognition.face_encodings(img)[0]
    known_faces.append(enc)
    known_people.append(file_name.replace('.png', ''))


def is_known(idx: int, cap: VideoCapture, crop=True, shrink=False):
    """Wether we recognize one person in the interpreter box or not"""
    frame = get_frame(idx, cap)
    if crop:
        frame = crop_interpreter(frame)
    if shrink:
        frame = cv2.resize(frame, None, fx=0.6, fy=0.6, interpolation=cv2.INTER_AREA)
    frame = np.ascontiguousarray(frame[:, :, :3], dtype=np.uint8)
    encodings = face_recognition.face_encodings(frame)
    for enc in encodings:
        matches = face_recognition.compare_faces(known_faces, enc)
        if any(matches):
            return known_people[np.argmax(matches)]
    return None


# false, ..., false, true, ..., true, false, ..., false
def bsearch(l: int, r: int, predicate):
    """Binary search on a sequence like [false, ..., false, true, ..., true]. Returns index of first true.
    Helps optimally search for the start and end indexes where the interpreter is present"""
    res = r
    while l <= r:
        m = (l + r) // 2
        if predicate(m):
            res = m
            r = m - 1
        else:
            l = m + 1  # noqa: E741
    return res

# %%
def do_segment(path: str):
    cap, fps, frame_count = get_vid_metadata(path)
    stride = (
        fps * 60 * 15
    )  # 30 min of SL at least (required by law) but let's search in chunks of 15 mins so we don't jump over if a tiny bit less than 30 mins
    true_idx = -1
    interpreter = None
    for i in range(0, frame_count, int(stride)):
        interpreter = is_known(i, cap)
        if interpreter:
            true_idx = i
            break
    if true_idx == -1:
        return None

    start = bsearch(0, true_idx, lambda x: is_known(x, cap))
    first_false = bsearch(true_idx, frame_count - 1, lambda x: not is_known(x, cap))

    if first_false < frame_count and not is_known(first_false, cap):
        end = first_false - 1
    else:
        end = frame_count - 1

    return start, end, interpreter


for root, _, files in os.walk(ROOT_DIR):
    for file in files:
        if file.endswith('.seg.mp4') or file.endswith('.seg.mkv'):
            continue

        if not file.endswith('.mp4') and not file.endswith('.mkv'):
            continue
        vid = os.path.join(root, file)
        seg = vid.replace('.mp4', '.json').replace('.mkv', '.json')
        if os.path.exists(seg):
            print(f'Skipping {seg}')
            continue
        segment = do_segment(vid)
        if not segment:
            print(f'NONE FOR {seg}!!!')
            continue
        with open(seg, 'w') as f:
            json.dump(
                {'start': segment[0], 'end': segment[1], 'interpreter': segment[2]}, f
            )
        print(seg)

# %% [markdown]
# ### Sometimes the interpreter disappears for some time and reappears quite later. Do find them out

# %%
import json
import os


# Reuse the do segment logic but apply it BEFORE the identified segment and AFTER the identified segment
# (Originally this function was used to FIND the segment. Now see if there are some other, weird segments
# we missed.)
def do_segment_weird(path: str, startx: int, endx: int):
    cap, fps, frame_count = get_vid_metadata(path)
    frame_count -= 1
    stride = fps * 60 * 5  # 5 min
    stride = min(stride, frame_count // 12)
    true_idx = -1
    interpreter = None
    if startx == -1:
        startx = 0
    if endx == -1:
        endx = frame_count
    for i in range(startx, endx, int(stride)):
        interpreter = is_known(i, cap)
        if interpreter:
            true_idx = i
            break
    if true_idx == -1:
        return None

    start = bsearch(0, true_idx, lambda x: is_known(x, cap))
    first_false = bsearch(true_idx, frame_count - 1, lambda x: not is_known(x, cap))

    if first_false < frame_count and not is_known(first_false, cap):
        end = first_false - 1
    else:
        end = frame_count - 1

    return start, end, interpreter


for root, _, files in os.walk(ROOT_DIR):
    for file in files:
        if file.endswith('.seg.mp4') or file.endswith('.seg.mkv'):
            continue

        if not file.endswith('.mp4') and not file.endswith('.mkv'):
            continue
        vid = os.path.join(root, file)
        seg = vid.replace('.mp4', '.json').replace('.mkv', '.json')
        if not os.path.exists(seg):
            print(f'Skipping {seg}')
            continue

        with open(seg) as f:
            seg = json.load(f)

        print(f'trying {file}')
        segment = do_segment_weird(vid, -1, seg['start'] - 1)
        if segment:
            print(file + ' BEFORE')
        segment = do_segment_weird(vid, seg['end'] + 1, -1)
        if segment:
            print(file + ' AFTER')

# %%
for root, _, files in os.walk(ROOT_DIR):
    for file in files:
        if file.endswith('.seg.mp4') or file.endswith('.seg.mkv'):
            continue

        if not file.endswith('.mp4') and not file.endswith('.mkv'):
            continue
        vid = os.path.join(root, file)
        seg = vid.replace('.mp4', '.json').replace('.mkv', '.json')
        if not os.path.exists(seg):
            print(f'Skipping {seg}')
            continue

        with open(seg) as f:
            seg = json.load(f)

        if isinstance(seg, list):
            continue

        cap, fps, frame_count = get_vid_metadata(vid)

        start = seg['end'] + 1
        end = min(seg['end'] + 1 + int(10 * 60 * fps), frame_count)

        fc = False
        for i in range(start, end, int(5 * fps)):
            if is_known(i, cap, shrink=True):
                print(vid + 'first_case  ' + str(i))
                fc = True
                break

        if fc:
            continue

        start = seg['end'] - 1
        end = max(seg['start'], seg['end'] - 1 - int(10 * 60 * fps))

        for i in range(start, end, int(-5 * fps)):
            if not is_known(i, cap, shrink=True):
                print(vid + 'second_case  ' + str(i))
                break

        print(f'Done with {vid}')
        # incepe de la end - 1 (spre inceput), ia la fiecare 5 secunde timp de 10 minute daca nu este interpret.

# %%
first_case = set()

with open('a.txt', 'r', encoding='utf-8') as f:
    for line in f:
        if 'first_case' in line:
            split = line.split('first_case  ')
            vid_path = split[0]
            idx = int(split[1])

            seg = vid_path.replace('.mp4', '.json').replace('.mkv', '.json')
            with open(seg) as f:
                seg = json.load(f)

            yes = 0
            no = 0

            cap, fps, _ = get_vid_metadata(vid_path)

            start = idx
            end = min(seg['end'] - 1, int(idx + 3 * fps))

            for i in range(start, end + 1, 5):
                if not is_known(i, cap):
                    no += 1
                else:
                    yes += 1

            if no >= yes:
                first_case.add((vid_path, idx))
                print(vid_path + ' !!!')

            print(f'Done with {vid_path}')

            # de aici vezi daca exista 3 secunde fara content (din 5 in 5 cadre)

# %%
# in fata nu e content => bsearch [idx, end]

for vid_path, start in first_case:
    seg_path = vid_path.replace('.mp4', '.json').replace('.mkv', '.json')
    with open(seg_path) as f:
        seg = json.load(f)

    if isinstance(seg, list):
        continue

    cap, fps, frame_count = get_vid_metadata(vid_path)

    if not is_known(start, cap, shrink=True):
        raise ValueError()

    first_false = bsearch(
        start, frame_count - 1, lambda x: not is_known(x, cap, shrink=True)
    )

    if first_false < frame_count and not is_known(first_false, cap):
        end = first_false - 1
    else:
        print(f'skipped {vid_path}')
        continue

    if not is_known(end, cap, shrink=True):
        raise ValueError(vid)

    seg = [seg, {'start': start, 'end': end, 'interpreter': seg['interpreter']}]
    with open(seg_path, 'w') as f:
        json.dump(seg, f)
        print(seg_path)
# Out:
# skipped scraped/2021/08/13/2e049f12-0d83-4448-9864-875a77f071ef.mkv
# scraped/2021/12/14/cfd58d07-5b90-4601-8682-6c225dd7b4be.json
# scraped/2021/08/06/cd3fa7ca-5bd3-4622-93f3-0bd569ee3ed5.json
# scraped/2021/02/19/b4ea7651-3bf9-4be7-b68b-ea65337e173c.json
# scraped/2021/06/03/afb09472-54a9-487d-ad3f-884406fa0079.json
# scraped/2021/07/26/6a104128-9d43-4197-b625-816194b6a366.json
# scraped/2021/02/15/f45e0ec0-58a0-4469-b3a4-1d0aa8f688a2.json
# scraped/2021/06/29/6a303aa8-c6df-4dc3-bbe7-2309cca574e0.json
# scraped/2021/03/11/c5470d67-b194-4a3a-9454-7f0465466050.json
# scraped/2021/05/20/fe23b9b1-ca3a-4aae-a24a-085934fc1f5c.json
# scraped/2021/02/22/5027f027-5939-46f9-a96f-aeeac5556c5e.json
# scraped/2021/03/23/1c91ea95-d8d6-438b-89fe-89a21177f16c.json
# scraped/2021/04/02/5f505e87-eba0-4f2c-a312-ff51bb1af062.json
# scraped/2021/06/24/45625068-4f24-4cc2-ba13-0e31f8565359.json
# scraped/2021/05/25/19d268b5-7e2a-4ba9-97d1-8f3cea3b0516.json
# scraped/2021/06/10/a0f48b6c-80e5-4617-bbe6-0b1f73d3a6dc.json
# scraped/2021/03/31/67aec431-190c-4314-be48-f0ef1b9aac76.json
# scraped/2021/07/13/ac3d50c2-3903-4404-97c9-3cde9bd6c045.json
# scraped/2021/05/27/23c35833-b28a-43bb-b5bc-5d249b4941be.json
# scraped/2021/08/11/3f9e7dfb-01ed-4d21-a2b4-ea23917a560f.json
# scraped/2021/03/04/47ecbe64-3a18-4edd-a108-38e5b4960e06.json
# scraped/2021/04/29/81e9424c-fee6-436e-80aa-38d6b5ff062d.json
# scraped/2021/05/14/adf7d7b0-8412-4be9-a33b-2579d2fbd749.json
# scraped/2021/04/01/2286c78f-a862-4413-8370-e30d020dad1e.json
# scraped/2021/06/22/aacac8d3-f0de-4f51-818c-44f7bd845ddb.json
# scraped/2022/04/01/2d699517-7ad1-402c-9abc-6b60587bf008.json
# scraped/2021/03/02/bc8a1bbf-c288-4cbd-ac4a-39215fa6e648.json
# scraped/2021/04/14/c121a252-0611-4e81-8b7a-495037fdc007.json
# scraped/2021/03/12/3ce3d021-3cb2-4609-bb6f-8aa392291109.json
# scraped/2021/07/02/2944f474-f4b0-46b7-990f-de6c0b3410d7.json
# scraped/2021/01/21/541160db-c9e9-4445-850c-387c2d9a4b8d.json

# %%
second_case = set()

with open('b.txt', 'r', encoding='utf-8') as f:
    for line in f:
        if 'second_case' in line:
            split = line.split('second_case  ')
            vid_path = split[0]
            idx = int(split[1])

            seg = vid_path.replace('.mp4', '.json').replace('.mkv', '.json')
            with open(seg) as f:
                seg = json.load(f)

            if isinstance(seg, list):
                continue

            yes = 0
            no = 0

            cap, fps, _ = get_vid_metadata(vid_path)

            start = max(seg['start'], idx - 1)
            end = max(seg['start'], int(idx - 1 - 3 * fps))

            for i in range(start, end - 1, -5):
                if not is_known(i, cap):
                    no += 1
                else:
                    yes += 1

            if no >= yes:
                second_case.add((vid_path, idx))
                print(vid_path + ' !!!')

            print(f'Done with {vid_path}')

            # de aici vezi daca exista 3 secunde fara content (din 5 in 5 cadre)

# %%
# in spate nu e content => bsearch [start, idx] si [idx, end]

# in fata nu e content => bsearch [idx, end]

for vid_path, idx in second_case:
    seg_path = vid_path.replace('.mp4', '.json').replace('.mkv', '.json')
    with open(seg_path) as f:
        seg = json.load(f)

    if isinstance(seg, list):
        continue

    cap, fps, frame_count = get_vid_metadata(vid_path)

    if is_known(idx, cap, shrink=True):
        raise ValueError()

    first_false = bsearch(seg['start'], idx, lambda x: not is_known(x, cap))
    if first_false < frame_count and not is_known(first_false, cap):
        end = first_false - 1
    else:
        print(f'skipped {vid_path}')
        continue
    if not is_known(end, cap, shrink=True):
        raise ValueError(vid)
    if is_known(end + 1, cap, shrink=True):
        raise ValueError(vid)

    start = bsearch(idx, seg['end'], lambda x: is_known(x, cap))
    if not is_known(start, cap, shrink=True):
        raise ValueError(vid)
    if is_known(start - 1, cap, shrink=True):
        raise ValueError(vid)

    seg = [
        {'start': seg['start'], 'end': end, 'interpreter': seg['interpreter']},
        {'start': start, 'end': seg['end'], 'interpreter': seg['interpreter']},
    ]
    with open(seg_path, 'w') as f:
        json.dump(seg, f)
        print(seg_path)
# Out:
# scraped/2022/03/04/70c66d3f-98f0-4f81-9da9-87dc178f47a1.json
# scraped/2021/07/05/06695085-ca1d-40d4-b3c4-bf3c2858b297.json
# scraped/2021/03/16/e19db1f3-89b9-4585-af73-9c4718fa19c5.json
# scraped/2021/04/21/67577aa5-0b31-46d8-a6be-eaf65c0f02fc.json
# scraped/2021/05/04/a41c384a-3a5f-4144-92ff-8b846724ceaf.json
# scraped/2021/04/13/86bf98a5-a53d-4856-b2b1-ed7c4bcaf7dc.json
# scraped/2021/06/08/1ecb01ef-8e96-44c5-ba39-e701614092f9.json
# scraped/2021/07/06/eee51705-961b-4f15-82f0-1858620902e4.json
# scraped/2021/06/23/1ddca7d2-f7ab-4445-88ad-2541454f994f.json
# scraped/2021/03/18/eada8597-c6b3-47ec-92b1-ee837d598c66.json
# scraped/2021/02/26/d3859b70-d4e2-4afd-9669-d74a6c879c03.json
# scraped/2021/06/15/fcf31a6b-43dc-4810-892a-9513795f049a.json
# scraped/2021/03/01/d485f09d-dc2f-47ab-b1ef-5bf156f7ba94.json
# scraped/2021/07/09/3245adbc-7a94-49c1-8736-11b56a9d6ab6.json
# scraped/2021/05/10/21b433ba-f595-40e9-a1d7-ad3c5939a6d2.json
# scraped/2021/03/17/d2f2546b-adbf-4a92-8953-ec031621eefd.json
# scraped/2021/07/12/11bc4631-7d05-47c8-9fb6-86d871e36b3b.json
# scraped/2021/05/24/bca98dd6-c7e5-412a-8670-67fcc3245d67.json
# scraped/2021/03/15/721ba36a-c37c-4c46-9acf-549ece6dea56.json
# scraped/2021/03/22/977b1f9c-ae45-40d1-aa3c-807f25e66f41.json
# scraped/2021/07/30/b8c75b84-2f41-49b5-995a-f754d80b8383.json
# scraped/2021/02/17/91c10e85-9c47-4ced-8935-4a8bad474a10.json
# scraped/2021/04/09/d7b12583-045c-4cbd-9b37-3ea3c36fc73b.json
# scraped/2021/05/28/d5b75d20-23a7-4395-8092-804a275c9090.json
# scraped/2021/02/25/3855a0df-90f2-4abe-9720-72a29c68b41a.json
# scraped/2021/04/28/aaf646e8-a6a8-4a8e-b8e9-1b3c63adb415.json
# scraped/2021/05/26/272b57aa-a20e-4dfb-bc3f-0557fcc9ec11.json
# scraped/2021/05/13/8df3d221-d3b0-489c-8f4c-27b17d1897ed.json
# scraped/2021/04/05/61d4334a-c33d-4f64-982a-f51e1a64067c.json
# scraped/2021/04/06/3f9e6617-1d26-406e-aa57-bb1919f51d49.json
# scraped/2021/04/15/f3e4e141-6b9e-4069-a0be-8f09de0c77b1.json
# scraped/2021/06/17/da39a002-a1d1-4066-b368-68f40ae471b3.json
# scraped/2021/05/18/20473e5c-94ad-401c-9ff6-a9669bdd5f8b.json
# scraped/2021/01/28/24c48daa-5e72-4a13-b4a6-2ef16c6d86d9.json
# scraped/2021/02/24/37b93151-4774-4c93-ba13-9da111d3bc75.json
# scraped/2021/04/16/cd8663d5-7cc2-49eb-9c7f-a2de73bb5bf0.json
# scraped/2021/05/11/46733cb8-d4b6-4506-ae21-e28ea8f11733.json
# scraped/2021/04/26/fee5803a-9e60-4c21-8235-05411262079f.json
# scraped/2021/06/11/5cb5b2bb-6c53-4b18-8237-9201e6fcfecb.json
# scraped/2021/05/19/9dfbf246-b192-4ee6-bc4e-dd7484abe7b4.json
# scraped/2021/04/12/ec0807f4-8211-42b4-9edf-77780fd722be.json
# scraped/2021/07/07/f2308d5b-747d-4300-9d96-393749f9082f.json
# scraped/2021/02/23/dc680d75-62e6-4b17-972b-c7ff15970b3e.json
# scraped/2021/03/29/aa925aaa-9a0e-4b28-b899-72f724f55371.json
# scraped/2021/04/08/b1fdd7db-2ac8-422c-b37d-b3befc269a0e.json
# scraped/2021/03/24/8546a451-b10d-489b-a1aa-f124271edbd2.json
# scraped/2021/01/27/c93e44db-07ac-4e5a-803c-9e760f0aa283.json
# scraped/2021/03/19/a9ca1518-a37f-4a9d-bbe5-fe2fd04a572b.json
# scraped/2021/06/02/720b89e1-6efe-4f34-8cbf-05e1c35308d1.json
# scraped/2021/06/25/286e21a0-dfbf-453f-9f52-63c79846745f.json
# scraped/2021/02/18/f5bca5fe-cc90-4a1b-b647-d108c1a3c4ea.json
# scraped/2021/02/12/a359e7e6-c6da-4688-9d1a-6f70be3e7196.json
# scraped/2021/07/16/a2efbbc8-0b4d-4c50-976a-a6910b3fdffd.json
# scraped/2021/01/25/d3cde487-c6bb-4ed0-945f-82cc36910ea1.json
# scraped/2021/06/18/6d34b18e-bae3-40c3-a3bb-cdf0c3784c79.json
# scraped/2021/04/20/b4c73f83-3210-4b7e-961f-0f7e4c8bff6a.json
# scraped/2021/06/16/8a984841-234c-4a07-a3f9-baade48c836d.json
# scraped/2021/01/20/6a91b0eb-6cf9-48fe-a6b3-c7b5149fe8ab.json
# scraped/2021/02/16/860bb145-b3d9-4ed2-8ea9-64fcedc5c121.json
# scraped/2021/08/13/2e049f12-0d83-4448-9864-875a77f071ef.json
# scraped/2021/03/03/688412ea-8786-4088-b55a-01f933e47793.json
# scraped/2021/05/06/9dfd3f39-1bbb-459e-bc61-127e796bdf64.json
# scraped/2021/04/07/cb145eaf-9ff9-421c-b283-61b3ef44c91d.json
# scraped/2022/02/28/16ab67a5-b57b-4f97-b572-0fa6c383816a.json

# %% [markdown]
# ### Viz

# %%
import matplotlib.pyplot as plt

idx = 122007
vid = '2021/05/31/5a936525-9441-47de-a7e5-b5050b3a640a.mkv'

cap, _, _ = get_vid_metadata(os.path.join('scraped', vid))
frame = get_frame(idx, cap)
frame = crop_interpreter(frame)

plt.imshow(frame)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Crop segments with ffmpeg -- lossless quality

# %%
import os
import json
import shlex
import subprocess


ENCODER_TYPE = 'cpu'  # Options: "nvidia", "cpu"
QUALITY_SETTING = 20  # 0 is lossless (huge files). 18-24 is high quality.


def crop_segment(
    vid_path: str,
    output_path: str,
    start_frame: int,
    end_frame: int,
    fps: float,
    W: int,
    H: int,
    X: int,
    Y: int,
) -> bool:
    start_sec = start_frame / fps
    duration_sec = (end_frame - start_frame + 1) / fps

    crop_filter = f'crop={W}:{H}:{X}:{Y}'
    quiet_opts = ['-hide_banner', '-loglevel', 'error']

    command = [
        'ffmpeg',
        *quiet_opts,
        '-y',
        '-ss',
        f'{start_sec:.6f}',
        '-i',
        vid_path,
        '-t',
        f'{duration_sec:.6f}',
        '-vf',
        crop_filter,
    ]

    if ENCODER_TYPE == 'nvidia':
        encoder_opts = [
            '-c:v',
            'h264_nvenc',
            '-rc',
            'constqp',
            '-qp',
            str(QUALITY_SETTING),
            '-preset',
            'p1',
        ]
    elif ENCODER_TYPE == 'cpu':
        encoder_opts = [
            '-c:v',
            'libx264',
            '-crf',
            str(QUALITY_SETTING),
            '-preset',
            'superfast',
        ]
    else:
        raise ValueError(f'Unknown ENCODER_TYPE: {ENCODER_TYPE}')

    command.extend(encoder_opts)

    command.extend(
        [
            '-c:a',
            'copy',
            output_path,
        ]
    )

    try:
        subprocess.run(
            command,
            check=True,
            stdout=subprocess.DEVNULL,
            stderr=subprocess.PIPE,
            text=True,
        )
        return True
    except subprocess.CalledProcessError as e:
        print('--- FFMPEG ERROR ---')
        print(f'Error processing {vid_path} -> {output_path}')
        print(f'Command: {" ".join([shlex.quote(c) for c in command])}')
        print(f'Error Output: {e.stderr}')
        print('--------------------')
        return False
    except Exception as e:
        print('--- UNEXPECTED FFMPEG ERROR ---')
        print(f'Error processing {vid_path} -> {output_path}')
        print(f'Command: {" ".join([shlex.quote(c) for c in command])}')
        print(f'Exception: {e}')
        print('--------------------')
        return False


def get_w_h_fps(vid_path: str):
    command = [
        'ffprobe',
        '-v',
        'error',
        '-select_streams',
        'v:0',
        '-show_entries',
        'stream=width,height,r_frame_rate',
        '-of',
        'json',
        vid_path,
    ]

    try:
        result = subprocess.run(command, check=True, capture_output=True, text=True)
        metadata = json.loads(result.stdout)['streams'][0]

        w = int(metadata['width'])
        h = int(metadata['height'])

        # r_frame_rate is a fraction like "30/1" or "2997/100"
        num, den = metadata['r_frame_rate'].split('/')
        fps = float(num) / float(den)

        return w, h, fps

    except Exception as e:
        print(f'Error getting metadata for {vid_path}: {e}')
        print(f'ffprobe output: {result.stderr}')  # type: ignore
        raise


def enqueue(path: str):
    with open('queue.txt', 'a') as q:
        q.write(path + '\n')


for root, _, files in os.walk('scraped'):
    for file in files:
        if not file.endswith('.json'):
            continue

        json_path = os.path.join(root, file)
        vid_path = json_path.replace('.json', '.mp4')
        base_out_path = json_path.replace('.json', '.seg.mp4')

        if not os.path.exists(vid_path):
            vid_path = json_path.replace('.json', '.mkv')
            base_out_path = json_path.replace('.json', '.seg.mkv')

        if not os.path.exists(vid_path):
            print(f'No video found for {json_path}, skipping.')
            continue

        if os.path.exists(base_out_path):
            print(f'Skipping {vid_path} (base output already exists)')
            continue

        try:
            w, h, fps = get_w_h_fps(vid_path)
        except Exception as e:
            print(f'Skipping {vid_path} due to metadata error: {e}')
            continue

        if h == 720:
            X, Y = 952, 347
            W, H = 300, 322
        elif h == 432:
            X, Y = 571, 208
            W, H = 180, 193
        else:
            print(f'Skipping {vid_path}, height {h} not supported')
            continue

        with open(json_path) as f:
            segment = json.load(f)

        # Track whether everything for this video was processed OK
        process_ok = True

        if not isinstance(segment, list):
            print(f'Processing {vid_path}...')
            process_ok = crop_segment(
                vid_path,
                base_out_path,
                segment['start'],
                segment['end'],
                fps,
                W,
                H,
                X,
                Y,
            )
            if process_ok:
                enqueue(base_out_path)
        else:
            print(f'Processing {vid_path} as {len(segment)} segments...')
            base_name, ext = os.path.splitext(base_out_path)

            if not segment:
                print('No segments defined; not deleting original.')
                process_ok = False
            else:
                for i, seg in enumerate(segment):
                    out_path_i = f'{base_name}_{i}{ext}'

                    if os.path.exists(out_path_i):
                        print(f'Skipping segment {i} (already exists)')
                        continue

                    ok = crop_segment(
                        vid_path,
                        out_path_i,
                        seg['start'],
                        seg['end'],
                        fps,
                        W,
                        H,
                        X,
                        Y,
                    )
                    if ok:
                        enqueue(out_path_i)
                    else:
                        process_ok = False

        if process_ok:
            try:
                os.remove(vid_path)
                print(f'Deleted original video {vid_path}')
            except OSError as e:
                print(f'Failed to delete original video {vid_path}: {e}')

        print(f'Finished {vid_path}')
# Out:
# Processing scraped/2022/05/03/12a79215-1497-4547-a42d-18511d15925b.mkv...
# Deleted original video scraped/2022/05/03/12a79215-1497-4547-a42d-18511d15925b.mkv
# Finished scraped/2022/05/03/12a79215-1497-4547-a42d-18511d15925b.mkv
# Processing scraped/2022/05/31/9c495d48-13f6-439d-92a3-bfc09b5cba6e.mkv...
# Deleted original video scraped/2022/05/31/9c495d48-13f6-439d-92a3-bfc09b5cba6e.mkv
# Finished scraped/2022/05/31/9c495d48-13f6-439d-92a3-bfc09b5cba6e.mkv
# Processing scraped/2022/05/23/914513d1-2aeb-48d2-a6c9-2738d533eb21.mkv...
# Deleted original video scraped/2022/05/23/914513d1-2aeb-48d2-a6c9-2738d533eb21.mkv
# Finished scraped/2022/05/23/914513d1-2aeb-48d2-a6c9-2738d533eb21.mkv
# Processing scraped/2022/05/13/6d59c679-f5a6-468a-823a-491ee2b8df52.mkv...
# Deleted original video scraped/2022/05/13/6d59c679-f5a6-468a-823a-491ee2b8df52.mkv
# Finished scraped/2022/05/13/6d59c679-f5a6-468a-823a-491ee2b8df52.mkv
# Processing scraped/2022/05/18/548a0e1c-c4f3-4c2c-a915-f46b303376c4.mkv...
# Deleted original video scraped/2022/05/18/548a0e1c-c4f3-4c2c-a915-f46b303376c4.mkv
# Finished scraped/2022/05/18/548a0e1c-c4f3-4c2c-a915-f46b303376c4.mkv
# Processing scraped/2022/05/12/e4c26328-f269-4bef-96bd-98074f041c47.mkv...
# Deleted original video scraped/2022/05/12/e4c26328-f269-4bef-96bd-98074f041c47.mkv
# Finished scraped/2022/05/12/e4c26328-f269-4bef-96bd-98074f041c47.mkv
# Processing scraped/2022/05/24/6dfbed91-b0d5-44df-9785-38a5e5130f51.mkv...
# Deleted original video scraped/2022/05/24/6dfbed91-b0d5-44df-9785-38a5e5130f51.mkv
# Finished scraped/2022/05/24/6dfbed91-b0d5-44df-9785-38a5e5130f51.mkv
# Processing scraped/2022/05/26/d383085f-15ee-4ac1-b1b8-8bb5b852c73e.mkv...
# Deleted original video scraped/2022/05/26/d383085f-15ee-4ac1-b1b8-8bb5b852c73e.mkv
# Finished scraped/2022/05/26/d383085f-15ee-4ac1-b1b8-8bb5b852c73e.mkv
# Processing scraped/2022/05/20/b4fbe6ff-6005-426c-bb3f-10295bbf9ca8.mkv...
# Deleted original video scraped/2022/05/20/b4fbe6ff-6005-426c-bb3f-10295bbf9ca8.mkv
# Finished scraped/2022/05/20/b4fbe6ff-6005-426c-bb3f-10295bbf9ca8.mkv
# Processing scraped/2022/05/11/4adf6a33-1c07-4a9e-bb1e-04c9b805645d.mkv...
# Deleted original video scraped/2022/05/11/4adf6a33-1c07-4a9e-bb1e-04c9b805645d.mkv
# Finished scraped/2022/05/11/4adf6a33-1c07-4a9e-bb1e-04c9b805645d.mkv
# Processing scraped/2022/05/27/e53a90fe-acac-4e7b-ac2f-1b85d2d0c804.mkv...
# Deleted original video scraped/2022/05/27/e53a90fe-acac-4e7b-ac2f-1b85d2d0c804.mkv
# Finished scraped/2022/05/27/e53a90fe-acac-4e7b-ac2f-1b85d2d0c804.mkv
# Processing scraped/2022/05/02/ec547c21-ed80-4f9a-a435-98334f7e5030.mkv...
# Deleted original video scraped/2022/05/02/ec547c21-ed80-4f9a-a435-98334f7e5030.mkv
# Finished scraped/2022/05/02/ec547c21-ed80-4f9a-a435-98334f7e5030.mkv
# Processing scraped/2022/05/25/c571d28a-2983-4fec-8375-62c13c98a3c7.mkv...
# Deleted original video scraped/2022/05/25/c571d28a-2983-4fec-8375-62c13c98a3c7.mkv
# Finished scraped/2022/05/25/c571d28a-2983-4fec-8375-62c13c98a3c7.mkv
# Processing scraped/2022/05/04/4d341833-81e7-44ff-82e9-cadf8746a32a.mkv...
# Deleted original video scraped/2022/05/04/4d341833-81e7-44ff-82e9-cadf8746a32a.mkv
# Finished scraped/2022/05/04/4d341833-81e7-44ff-82e9-cadf8746a32a.mkv
# Processing scraped/2022/05/30/caed4342-7562-496f-a4f6-afe149f5153d.mkv...
# Deleted original video scraped/2022/05/30/caed4342-7562-496f-a4f6-afe149f5153d.mkv
# Finished scraped/2022/05/30/caed4342-7562-496f-a4f6-afe149f5153d.mkv
# Processing scraped/2022/05/17/e1c7bd13-5eae-4750-bf92-46f87ad77a09.mkv...
# Deleted original video scraped/2022/05/17/e1c7bd13-5eae-4750-bf92-46f87ad77a09.mkv
# Finished scraped/2022/05/17/e1c7bd13-5eae-4750-bf92-46f87ad77a09.mkv
# Processing scraped/2022/05/19/b792e0b1-5987-4da4-851c-081a5a47165b.mkv...
# Deleted original video scraped/2022/05/19/b792e0b1-5987-4da4-851c-081a5a47165b.mkv
# Finished scraped/2022/05/19/b792e0b1-5987-4da4-851c-081a5a47165b.mkv
# No video found for scraped/2022/10/05/6cb29709-bd45-4a2d-abbf-2bade8ba40c5.json, skipping.
# No video found for scraped/2022/10/10/1d020762-4fdf-49d3-be96-23fc6e638cff.json, skipping.
# No video found for scraped/2022/10/21/e64baa59-575a-4027-8a51-346eb3953b0b.json, skipping.
# No video found for scraped/2022/10/31/686dd9c8-31e3-41a1-8d52-633f0f0e1563.json, skipping.
# No video found for scraped/2022/10/13/881804d5-1f64-49f9-9acf-80ddb119ba9c.json, skipping.
# No video found for scraped/2022/10/18/a85bd8ff-e22c-4b83-9e9a-c956979269e0.json, skipping.
# No video found for scraped/2022/10/12/d7e64f18-b254-416f-b01a-e4597c67bb84.json, skipping.
# No video found for scraped/2022/10/24/6fe58d57-b58c-4f28-bde0-b9768b757d57.json, skipping.
# No video found for scraped/2022/10/26/19a43cc9-af86-4948-ab29-044b66cd595b.json, skipping.
# No video found for scraped/2022/10/20/7ab8f8fe-ed53-4af6-afb8-73572f0583f5.json, skipping.
# No video found for scraped/2022/10/14/01f450a7-5f14-4445-b8ac-9f0ecbc7d2aa.json, skipping.
# No video found for scraped/2022/10/27/42d3bd71-7be4-4bcf-97e0-58bdd32d491a.json, skipping.
# No video found for scraped/2022/10/06/5f5fcfec-f9a0-4fc6-a260-b077cbb41b97.json, skipping.
# No video found for scraped/2022/10/25/9776bf65-de3e-4f40-b2c8-7cd9990ba302.json, skipping.
# No video found for scraped/2022/10/28/39cc56d4-1356-44ad-badd-131f9090cc9c.json, skipping.
# No video found for scraped/2022/10/17/7ef4d36a-9dc5-4327-a38b-c0a92d3f0d8f.json, skipping.
# No video found for scraped/2022/10/19/e324bf2f-9312-4577-84fb-fec45d50f1fd.json, skipping.
# Processing scraped/2022/03/22/4dc3ccf4-c451-4eda-b40a-8aa46c775d32.mkv...
# Deleted original video scraped/2022/03/22/4dc3ccf4-c451-4eda-b40a-8aa46c775d32.mkv
# Finished scraped/2022/03/22/4dc3ccf4-c451-4eda-b40a-8aa46c775d32.mkv
# Processing scraped/2022/03/10/1012d789-cd5f-44c8-a786-ce19ecbfdfdd.mkv...
# Deleted original video scraped/2022/03/10/1012d789-cd5f-44c8-a786-ce19ecbfdfdd.mkv
# Finished scraped/2022/03/10/1012d789-cd5f-44c8-a786-ce19ecbfdfdd.mkv
# Processing scraped/2022/03/21/094501e0-b8a9-47a7-8843-0f2c789113cf.mkv...
# Deleted original video scraped/2022/03/21/094501e0-b8a9-47a7-8843-0f2c789113cf.mkv
# Finished scraped/2022/03/21/094501e0-b8a9-47a7-8843-0f2c789113cf.mkv
# Processing scraped/2022/03/03/9de588e0-b3d1-407b-91a4-24d07b58d240.mkv...
# Deleted original video scraped/2022/03/03/9de588e0-b3d1-407b-91a4-24d07b58d240.mkv
# Finished scraped/2022/03/03/9de588e0-b3d1-407b-91a4-24d07b58d240.mkv
# Processing scraped/2022/03/15/6d7a3498-5d0f-4f89-881c-0df8ad7560d9.mkv...
# Deleted original video scraped/2022/03/15/6d7a3498-5d0f-4f89-881c-0df8ad7560d9.mkv
# Finished scraped/2022/03/15/6d7a3498-5d0f-4f89-881c-0df8ad7560d9.mkv
# Processing scraped/2022/03/18/8951b32d-245e-4665-ba00-2c6df036157b.mkv...
# Deleted original video scraped/2022/03/18/8951b32d-245e-4665-ba00-2c6df036157b.mkv
# Finished scraped/2022/03/18/8951b32d-245e-4665-ba00-2c6df036157b.mkv
# Processing scraped/2022/03/16/b42000cd-0a59-457f-802d-1b15925e783f.mkv...
# Deleted original video scraped/2022/03/16/b42000cd-0a59-457f-802d-1b15925e783f.mkv
# Finished scraped/2022/03/16/b42000cd-0a59-457f-802d-1b15925e783f.mkv
# Processing scraped/2022/03/14/ea14c2ed-d8b9-4db3-b542-952cffcf9ff3.mkv...
# Deleted original video scraped/2022/03/14/ea14c2ed-d8b9-4db3-b542-952cffcf9ff3.mkv
# Finished scraped/2022/03/14/ea14c2ed-d8b9-4db3-b542-952cffcf9ff3.mkv
# Processing scraped/2022/03/02/2c7a3e92-c0ff-4f53-871d-5e5e026f9284.mkv...
# Deleted original video scraped/2022/03/02/2c7a3e92-c0ff-4f53-871d-5e5e026f9284.mkv
# Finished scraped/2022/03/02/2c7a3e92-c0ff-4f53-871d-5e5e026f9284.mkv
# Processing scraped/2022/03/04/70c66d3f-98f0-4f81-9da9-87dc178f47a1.mkv as 2 segments...
# Deleted original video scraped/2022/03/04/70c66d3f-98f0-4f81-9da9-87dc178f47a1.mkv
# Finished scraped/2022/03/04/70c66d3f-98f0-4f81-9da9-87dc178f47a1.mkv
# Processing scraped/2022/03/28/4cf85149-7376-441b-bcd5-cbb2aff74aef.mkv...
# Deleted original video scraped/2022/03/28/4cf85149-7376-441b-bcd5-cbb2aff74aef.mkv
# Finished scraped/2022/03/28/4cf85149-7376-441b-bcd5-cbb2aff74aef.mkv
# Processing scraped/2022/03/30/905b31fd-5c67-4a5d-9246-d9b8aa5902ee.mkv...
# Deleted original video scraped/2022/03/30/905b31fd-5c67-4a5d-9246-d9b8aa5902ee.mkv
# Finished scraped/2022/03/30/905b31fd-5c67-4a5d-9246-d9b8aa5902ee.mkv
# No video found for scraped/2022/12/05/d7896499-9f17-4184-8b8e-28ed176c64f8.json, skipping.
# No video found for scraped/2022/12/22/821a4f23-eee8-4b8e-802a-5c258a982f00.json, skipping.
# No video found for scraped/2022/12/29/32cac7b4-9fd1-4e98-affb-59a6c5dddcd5.json, skipping.
# No video found for scraped/2022/12/10/2dc28f35-c043-4ae3-b0da-c8b524400380.json, skipping.
# No video found for scraped/2022/12/21/732bb9f6-da7b-45ad-a768-b81c252bb9e7.json, skipping.
# No video found for scraped/2022/12/15/78aeeeaf-8867-4e4a-af78-1cdeb84e068d.json, skipping.
# No video found for scraped/2022/12/23/78d2a76f-0842-485e-8cc2-21457159f7b7.json, skipping.
# No video found for scraped/2022/12/13/d5330f15-0606-4321-b296-47f894e438aa.json, skipping.
# No video found for scraped/2022/12/12/38461e89-b6aa-4d39-af93-28c8d38e8883.json, skipping.
# No video found for scraped/2022/12/20/71a11c92-7d0e-4077-bb82-d3ac919a2fb1.json, skipping.
# No video found for scraped/2022/12/09/ac5d9a3c-e2ac-4749-8c79-e255f2d986b2.json, skipping.
# No video found for scraped/2022/12/16/f781cb80-763b-4ead-b916-f4e93766902a.json, skipping.
# No video found for scraped/2022/12/14/065d1fdd-2fb6-4a4c-be29-db5f3d4887cb.json, skipping.
# No video found for scraped/2022/12/11/c9e1e24c-3acc-4b8b-95db-bf8fd765619b.json, skipping.
# No video found for scraped/2022/12/27/0d0b1e3b-d323-40a2-b36f-1ceae03c8abf.json, skipping.
# No video found for scraped/2022/12/06/d0185eab-79fb-49b2-8d7e-12fdb301d757.json, skipping.
# No video found for scraped/2022/12/02/4e9a898c-66a1-48eb-95db-8185017e276a.json, skipping.
# No video found for scraped/2022/12/08/36e8756c-89fd-49b6-8026-02c4ea2154ee.json, skipping.
# No video found for scraped/2022/12/04/9e05bfe5-e8de-4591-80bb-74a4c76227ce.json, skipping.
# No video found for scraped/2022/12/28/8d4d7e66-032d-46a9-9c89-009b428a0420.json, skipping.
# No video found for scraped/2022/12/30/c474506a-f923-436a-af81-0ca34ae23039.json, skipping.
# No video found for scraped/2022/12/07/54429dd6-62f1-4d08-b44b-4199f8d1e76d.json, skipping.
# No video found for scraped/2022/12/19/d6343555-eb12-4cf3-8927-4345cbf024d3.json, skipping.
# No video found for scraped/2022/09/05/6b96f97a-370f-4810-bad1-b6dd47cdd2ae.json, skipping.
# No video found for scraped/2022/09/22/7b551a23-a259-4268-8e60-e729f0224e6c.json, skipping.
# No video found for scraped/2022/09/29/d6003229-3b6b-41ff-b5f1-c733150b743d.json, skipping.
# No video found for scraped/2022/09/15/bdf0902f-f5da-4f9e-96cc-ad5978a50504.json, skipping.
# No video found for scraped/2022/09/12/18be5501-10ed-4748-ab45-7706902fc883.json, skipping.
# No video found for scraped/2022/09/26/4699a82c-df2c-4c60-bcc9-e5c10646b1c0.json, skipping.
# No video found for scraped/2022/09/16/390f93c4-cf8d-4b20-bc6d-1a0b0ebd3686.json, skipping.
# No video found for scraped/2022/09/01/bb25fb10-fd82-4578-b165-8c2faeb393d6.json, skipping.
# No video found for scraped/2022/09/14/5fb10090-20b2-42b8-b816-fa189488ce3b.json, skipping.
# No video found for scraped/2022/09/27/ce47e3de-a240-43ac-9780-282ab7a68911.json, skipping.
# No video found for scraped/2022/09/06/fd2897bb-594b-495b-a87c-d25cee64cdd5.json, skipping.
# No video found for scraped/2022/09/02/5db84f47-9b98-4db7-a035-433e1d03e596.json, skipping.
# No video found for scraped/2022/09/08/35d9097c-caa9-421a-8d9e-b6be5bf0f52b.json, skipping.
# No video found for scraped/2022/09/30/293c16f1-e87c-4dac-9bdc-a657620c5984.json, skipping.
# No video found for scraped/2022/09/07/143d8636-2e48-454e-a289-d9bf52ca0f3a.json, skipping.
# No video found for scraped/2022/09/19/57c39d7e-4010-4043-8798-fd57c5185b8e.json, skipping.
# Processing scraped/2022/01/05/9f33da48-0eba-4838-b9f3-5a26d9d479cf.mkv...
# Deleted original video scraped/2022/01/05/9f33da48-0eba-4838-b9f3-5a26d9d479cf.mkv
# Finished scraped/2022/01/05/9f33da48-0eba-4838-b9f3-5a26d9d479cf.mkv
# Processing scraped/2022/01/10/36380592-ed3c-49d9-adc4-79e12bd71cd1.mkv...
# Deleted original video scraped/2022/01/10/36380592-ed3c-49d9-adc4-79e12bd71cd1.mkv
# Finished scraped/2022/01/10/36380592-ed3c-49d9-adc4-79e12bd71cd1.mkv
# Processing scraped/2022/01/21/df335b3b-78d8-4e6a-9293-581b388d649a.mkv...
# Deleted original video scraped/2022/01/21/df335b3b-78d8-4e6a-9293-581b388d649a.mkv
# Finished scraped/2022/01/21/df335b3b-78d8-4e6a-9293-581b388d649a.mkv
# Processing scraped/2022/01/03/726e55a6-7499-4167-9fb7-c1451b3c21ac.mkv...
# Deleted original video scraped/2022/01/03/726e55a6-7499-4167-9fb7-c1451b3c21ac.mkv
# Finished scraped/2022/01/03/726e55a6-7499-4167-9fb7-c1451b3c21ac.mkv
# Processing scraped/2022/01/31/77bf7780-a955-46b4-8c31-1cafdf62e045.mkv...
# Deleted original video scraped/2022/01/31/77bf7780-a955-46b4-8c31-1cafdf62e045.mkv
# Finished scraped/2022/01/31/77bf7780-a955-46b4-8c31-1cafdf62e045.mkv
# Processing scraped/2022/01/13/519bc148-431f-48b9-a718-c0d9c1698b12.mkv...
# Deleted original video scraped/2022/01/13/519bc148-431f-48b9-a718-c0d9c1698b12.mkv
# Finished scraped/2022/01/13/519bc148-431f-48b9-a718-c0d9c1698b12.mkv
# Processing scraped/2022/01/18/a883d50d-0c01-44cd-bc0c-85ac62a5d49f.mkv...
# Deleted original video scraped/2022/01/18/a883d50d-0c01-44cd-bc0c-85ac62a5d49f.mkv
# Finished scraped/2022/01/18/a883d50d-0c01-44cd-bc0c-85ac62a5d49f.mkv
# Processing scraped/2022/01/12/075e644b-a7fd-42f7-8054-cb6ebbd28b31.mkv...
# Deleted original video scraped/2022/01/12/075e644b-a7fd-42f7-8054-cb6ebbd28b31.mkv
# Finished scraped/2022/01/12/075e644b-a7fd-42f7-8054-cb6ebbd28b31.mkv
# Processing scraped/2022/01/24/d369021c-3003-405a-b2dc-1bc2c2843b16.mkv...
# Deleted original video scraped/2022/01/24/d369021c-3003-405a-b2dc-1bc2c2843b16.mkv
# Finished scraped/2022/01/24/d369021c-3003-405a-b2dc-1bc2c2843b16.mkv
# Processing scraped/2022/01/26/fc2b26a9-14dd-487b-9854-b71dea98c8fb.mkv...
# Deleted original video scraped/2022/01/26/fc2b26a9-14dd-487b-9854-b71dea98c8fb.mkv
# Finished scraped/2022/01/26/fc2b26a9-14dd-487b-9854-b71dea98c8fb.mkv
# Processing scraped/2022/01/20/f92c2277-86b9-4ec4-8240-a4c46c5b7e16.mkv...
# Deleted original video scraped/2022/01/20/f92c2277-86b9-4ec4-8240-a4c46c5b7e16.mkv
# Finished scraped/2022/01/20/f92c2277-86b9-4ec4-8240-a4c46c5b7e16.mkv
# Processing scraped/2022/01/14/2d5ae2bd-feee-44e2-9d6b-4c65a0575f57.mkv...
# Deleted original video scraped/2022/01/14/2d5ae2bd-feee-44e2-9d6b-4c65a0575f57.mkv
# Finished scraped/2022/01/14/2d5ae2bd-feee-44e2-9d6b-4c65a0575f57.mkv
# Processing scraped/2022/01/11/a04c3241-6f5c-471f-9b6a-76ac1827cef3.mkv...
# Deleted original video scraped/2022/01/11/a04c3241-6f5c-471f-9b6a-76ac1827cef3.mkv
# Finished scraped/2022/01/11/a04c3241-6f5c-471f-9b6a-76ac1827cef3.mkv
# Processing scraped/2022/01/27/7fd21bf6-8a60-4666-b5c9-9c364d375270.mkv...
# Deleted original video scraped/2022/01/27/7fd21bf6-8a60-4666-b5c9-9c364d375270.mkv
# Finished scraped/2022/01/27/7fd21bf6-8a60-4666-b5c9-9c364d375270.mkv
# Processing scraped/2022/01/06/5e54b6f0-2533-4adb-ac3b-dbb97ae6bdab.mkv...
# Deleted original video scraped/2022/01/06/5e54b6f0-2533-4adb-ac3b-dbb97ae6bdab.mkv
# Finished scraped/2022/01/06/5e54b6f0-2533-4adb-ac3b-dbb97ae6bdab.mkv
# Processing scraped/2022/01/25/d51b56b4-c2c6-481f-b5a3-d19acd4f45bd.mkv...
# Deleted original video scraped/2022/01/25/d51b56b4-c2c6-481f-b5a3-d19acd4f45bd.mkv
# Finished scraped/2022/01/25/d51b56b4-c2c6-481f-b5a3-d19acd4f45bd.mkv
# Processing scraped/2022/01/04/8481709e-68a7-42e0-9155-a43be4544997.mkv...
# Deleted original video scraped/2022/01/04/8481709e-68a7-42e0-9155-a43be4544997.mkv
# Finished scraped/2022/01/04/8481709e-68a7-42e0-9155-a43be4544997.mkv
# Processing scraped/2022/01/28/4e2fbb5b-8718-433b-8799-4c3d268c60f1.mkv...
# Deleted original video scraped/2022/01/28/4e2fbb5b-8718-433b-8799-4c3d268c60f1.mkv
# Finished scraped/2022/01/28/4e2fbb5b-8718-433b-8799-4c3d268c60f1.mkv
# Processing scraped/2022/01/17/bbbff871-4f3e-4b47-b1e6-6a8cf2233ae6.mkv...
# Deleted original video scraped/2022/01/17/bbbff871-4f3e-4b47-b1e6-6a8cf2233ae6.mkv
# Finished scraped/2022/01/17/bbbff871-4f3e-4b47-b1e6-6a8cf2233ae6.mkv
# Processing scraped/2022/01/07/04e62da8-17a3-4d1e-b219-af5b6b38c7c9.mkv...
# Deleted original video scraped/2022/01/07/04e62da8-17a3-4d1e-b219-af5b6b38c7c9.mkv
# Finished scraped/2022/01/07/04e62da8-17a3-4d1e-b219-af5b6b38c7c9.mkv
# Processing scraped/2022/01/19/0977b6a0-f4a5-4d16-8f62-44d4273fd012.mkv...
# Deleted original video scraped/2022/01/19/0977b6a0-f4a5-4d16-8f62-44d4273fd012.mkv
# Finished scraped/2022/01/19/0977b6a0-f4a5-4d16-8f62-44d4273fd012.mkv
# No video found for scraped/2022/11/22/a513be04-f144-460c-b140-30bfd373f07d.json, skipping.
# No video found for scraped/2022/11/29/b0215dda-ac54-4461-86b6-7a9a373d534c.json, skipping.
# No video found for scraped/2022/11/10/68752112-ee59-4bc8-8193-724cb2b2f900.json, skipping.
# No video found for scraped/2022/11/21/6d12f0bc-749b-4032-88a1-56c6f9ff7472.json, skipping.
# No video found for scraped/2022/11/03/5993d9ec-4536-4d38-a90b-c253069e5581.json, skipping.
# No video found for scraped/2022/11/15/ba9a726a-e0c8-48fd-bd4c-45667b6ec984.json, skipping.
# No video found for scraped/2022/11/23/89d39c26-81f9-475d-9cc6-c7e5bbd6b2eb.json, skipping.
# No video found for scraped/2022/11/18/da5df8cc-5e92-42a4-b10d-f5808f0d8792.json, skipping.
# No video found for scraped/2022/11/24/443a9d77-4b92-48c7-9244-3900b4d9ed2c.json, skipping.
# No video found for scraped/2022/11/09/e8b31ebf-900b-4864-af83-ac8dd8f2017d.json, skipping.
# No video found for scraped/2022/11/16/7d206f8a-d3b8-4dd4-bad3-fa229bbaffc4.json, skipping.
# No video found for scraped/2022/11/01/9639911a-e20d-44c5-8b16-2f4fc06f548e.json, skipping.
# No video found for scraped/2022/11/14/8b42c2ec-1255-4236-b577-8c5bd6f5cb95.json, skipping.
# No video found for scraped/2022/11/11/13a5170f-1c4d-4421-93f2-e11c79c1cda6.json, skipping.
# No video found for scraped/2022/11/02/71fb41bf-1bf1-4ed6-a4e3-3d313b452432.json, skipping.
# No video found for scraped/2022/11/25/ca32de29-08ef-44df-ba12-62dfbb255339.json, skipping.
# No video found for scraped/2022/11/08/622302b0-9121-44b7-adbb-1c0e6535aa1f.json, skipping.
# No video found for scraped/2022/11/04/1e51ff4c-38b0-4637-8456-3994f1bea480.json, skipping.
# No video found for scraped/2022/11/28/666c011a-45cd-46bf-8a36-cba7c1c10d6a.json, skipping.
# No video found for scraped/2022/11/30/bbb4d099-e27b-4896-aac9-134cf7db5c25.json, skipping.
# No video found for scraped/2022/11/17/8730bef1-7cdb-4112-a886-aef9e506003d.json, skipping.
# No video found for scraped/2022/11/07/d9efcd23-06c5-4875-b689-cead6c5743bc.json, skipping.
# Processing scraped/2022/06/22/77da6850-dbc5-489e-b9df-5a836df45398.mkv...
# Deleted original video scraped/2022/06/22/77da6850-dbc5-489e-b9df-5a836df45398.mkv
# Finished scraped/2022/06/22/77da6850-dbc5-489e-b9df-5a836df45398.mkv
# Processing scraped/2022/06/29/215d0f09-cb02-49bd-bdb5-2c3347f9c654.mkv...
# Deleted original video scraped/2022/06/29/215d0f09-cb02-49bd-bdb5-2c3347f9c654.mkv
# Finished scraped/2022/06/29/215d0f09-cb02-49bd-bdb5-2c3347f9c654.mkv
# Processing scraped/2022/06/10/f5476931-0dc2-46db-908b-27bd7f81824c.mkv...
# Deleted original video scraped/2022/06/10/f5476931-0dc2-46db-908b-27bd7f81824c.mkv
# Finished scraped/2022/06/10/f5476931-0dc2-46db-908b-27bd7f81824c.mkv
# Processing scraped/2022/06/21/46cd1e24-8fa4-4faf-bf78-c3f7e09e9c60.mkv...
# Deleted original video scraped/2022/06/21/46cd1e24-8fa4-4faf-bf78-c3f7e09e9c60.mkv
# Finished scraped/2022/06/21/46cd1e24-8fa4-4faf-bf78-c3f7e09e9c60.mkv
# Processing scraped/2022/06/03/10cd5878-517d-4630-9492-80349aba7821.mkv...
# Deleted original video scraped/2022/06/03/10cd5878-517d-4630-9492-80349aba7821.mkv
# Finished scraped/2022/06/03/10cd5878-517d-4630-9492-80349aba7821.mkv
# Processing scraped/2022/06/15/2b7f9497-1a4c-4883-acb6-1f78f9489441.mkv...
# Deleted original video scraped/2022/06/15/2b7f9497-1a4c-4883-acb6-1f78f9489441.mkv
# Finished scraped/2022/06/15/2b7f9497-1a4c-4883-acb6-1f78f9489441.mkv
# Processing scraped/2022/06/23/8f63d9eb-e6a9-479f-b96b-da3397270a64.mkv...
# Deleted original video scraped/2022/06/23/8f63d9eb-e6a9-479f-b96b-da3397270a64.mkv
# Finished scraped/2022/06/23/8f63d9eb-e6a9-479f-b96b-da3397270a64.mkv
# Processing scraped/2022/06/13/0bb1a521-c109-4c92-9e66-b3888cc0baa6.mkv...
# Deleted original video scraped/2022/06/13/0bb1a521-c109-4c92-9e66-b3888cc0baa6.mkv
# Finished scraped/2022/06/13/0bb1a521-c109-4c92-9e66-b3888cc0baa6.mkv
# Processing scraped/2022/06/24/d13107a6-695f-4b90-9acd-b58b51464bd9.mkv...
# Deleted original video scraped/2022/06/24/d13107a6-695f-4b90-9acd-b58b51464bd9.mkv
# Finished scraped/2022/06/24/d13107a6-695f-4b90-9acd-b58b51464bd9.mkv
# Processing scraped/2022/06/20/2a40d2cd-a6f3-47a5-8ce7-7ff6c2119a5c.mkv...
# Deleted original video scraped/2022/06/20/2a40d2cd-a6f3-47a5-8ce7-7ff6c2119a5c.mkv
# Finished scraped/2022/06/20/2a40d2cd-a6f3-47a5-8ce7-7ff6c2119a5c.mkv
# Processing scraped/2022/06/09/ab4ae04c-81ce-4bf5-9904-9e2178d2c5b5.mkv...
# Deleted original video scraped/2022/06/09/ab4ae04c-81ce-4bf5-9904-9e2178d2c5b5.mkv
# Finished scraped/2022/06/09/ab4ae04c-81ce-4bf5-9904-9e2178d2c5b5.mkv
# Processing scraped/2022/06/16/926250fd-e5d5-4494-b7ac-49bf5baf3858.mkv...
# Deleted original video scraped/2022/06/16/926250fd-e5d5-4494-b7ac-49bf5baf3858.mkv
# Finished scraped/2022/06/16/926250fd-e5d5-4494-b7ac-49bf5baf3858.mkv
# Processing scraped/2022/06/01/6bcfe6ba-e9d4-4346-9a37-99c4c57f7596.mkv...
# Deleted original video scraped/2022/06/01/6bcfe6ba-e9d4-4346-9a37-99c4c57f7596.mkv
# Finished scraped/2022/06/01/6bcfe6ba-e9d4-4346-9a37-99c4c57f7596.mkv
# Processing scraped/2022/06/14/3d9bea56-fd55-4c7c-b39b-91d555494ca8.mkv...
# Deleted original video scraped/2022/06/14/3d9bea56-fd55-4c7c-b39b-91d555494ca8.mkv
# Finished scraped/2022/06/14/3d9bea56-fd55-4c7c-b39b-91d555494ca8.mkv
# Processing scraped/2022/06/27/fc693551-cc2c-443a-b9c0-d57e16461422.mkv...
# Deleted original video scraped/2022/06/27/fc693551-cc2c-443a-b9c0-d57e16461422.mkv
# Finished scraped/2022/06/27/fc693551-cc2c-443a-b9c0-d57e16461422.mkv
# Processing scraped/2022/06/06/dc5eab37-526f-46b1-9786-55d1c10f1b0f.mkv...
# Deleted original video scraped/2022/06/06/dc5eab37-526f-46b1-9786-55d1c10f1b0f.mkv
# Finished scraped/2022/06/06/dc5eab37-526f-46b1-9786-55d1c10f1b0f.mkv
# Processing scraped/2022/06/02/0c67e696-bade-4878-b31a-cbb031349a35.mkv...
# Deleted original video scraped/2022/06/02/0c67e696-bade-4878-b31a-cbb031349a35.mkv
# Finished scraped/2022/06/02/0c67e696-bade-4878-b31a-cbb031349a35.mkv
# Processing scraped/2022/06/08/1b23be42-c59e-44f0-ae62-71647a530f63.mkv...
# Deleted original video scraped/2022/06/08/1b23be42-c59e-44f0-ae62-71647a530f63.mkv
# Finished scraped/2022/06/08/1b23be42-c59e-44f0-ae62-71647a530f63.mkv
# Processing scraped/2022/06/28/92df564e-e919-451c-b58d-b14ed8430887.mkv...
# Deleted original video scraped/2022/06/28/92df564e-e919-451c-b58d-b14ed8430887.mkv
# Finished scraped/2022/06/28/92df564e-e919-451c-b58d-b14ed8430887.mkv
# Processing scraped/2022/06/30/bd9f7d82-8713-4520-8f68-2ec9d4576c45.mkv...
# Deleted original video scraped/2022/06/30/bd9f7d82-8713-4520-8f68-2ec9d4576c45.mkv
# Finished scraped/2022/06/30/bd9f7d82-8713-4520-8f68-2ec9d4576c45.mkv
# Processing scraped/2022/06/07/6f5eef84-8f5e-4344-a847-cac08c282815.mkv...
# Deleted original video scraped/2022/06/07/6f5eef84-8f5e-4344-a847-cac08c282815.mkv
# Finished scraped/2022/06/07/6f5eef84-8f5e-4344-a847-cac08c282815.mkv
# Processing scraped/2022/02/22/ce31e8b4-ae55-4f27-9407-027b13a2100a.mkv...
# Deleted original video scraped/2022/02/22/ce31e8b4-ae55-4f27-9407-027b13a2100a.mkv
# Finished scraped/2022/02/22/ce31e8b4-ae55-4f27-9407-027b13a2100a.mkv
# Processing scraped/2022/02/10/8a1b719c-b0eb-448b-acc3-39866e86a278.mkv...
# Deleted original video scraped/2022/02/10/8a1b719c-b0eb-448b-acc3-39866e86a278.mkv
# Finished scraped/2022/02/10/8a1b719c-b0eb-448b-acc3-39866e86a278.mkv
# Processing scraped/2022/02/03/2688e47e-b11b-4430-a72f-97b79c9141c1.mkv...
# Deleted original video scraped/2022/02/03/2688e47e-b11b-4430-a72f-97b79c9141c1.mkv
# Finished scraped/2022/02/03/2688e47e-b11b-4430-a72f-97b79c9141c1.mkv
# Processing scraped/2022/02/15/0a2227fa-e36d-4e0b-8532-60cab169c177.mkv...
# Deleted original video scraped/2022/02/15/0a2227fa-e36d-4e0b-8532-60cab169c177.mkv
# Finished scraped/2022/02/15/0a2227fa-e36d-4e0b-8532-60cab169c177.mkv
# Processing scraped/2022/02/23/ef0b69d4-5acd-4343-bf67-dbb9b2bd747d.mkv...
# Deleted original video scraped/2022/02/23/ef0b69d4-5acd-4343-bf67-dbb9b2bd747d.mkv
# Finished scraped/2022/02/23/ef0b69d4-5acd-4343-bf67-dbb9b2bd747d.mkv
# Processing scraped/2022/02/18/f79c0a86-80e0-4309-a132-d52d0905e1ae.mkv...
# Deleted original video scraped/2022/02/18/f79c0a86-80e0-4309-a132-d52d0905e1ae.mkv
# Finished scraped/2022/02/18/f79c0a86-80e0-4309-a132-d52d0905e1ae.mkv
# Processing scraped/2022/02/24/99abf10d-68d5-4e87-97a2-79210f9ee8c1.mkv...
# Deleted original video scraped/2022/02/24/99abf10d-68d5-4e87-97a2-79210f9ee8c1.mkv
# Finished scraped/2022/02/24/99abf10d-68d5-4e87-97a2-79210f9ee8c1.mkv
# Processing scraped/2022/02/09/2687d652-8fa2-4a77-bafb-3cb7c61ead2e.mkv...
# Deleted original video scraped/2022/02/09/2687d652-8fa2-4a77-bafb-3cb7c61ead2e.mkv
# Finished scraped/2022/02/09/2687d652-8fa2-4a77-bafb-3cb7c61ead2e.mkv
# Processing scraped/2022/02/16/9334b34a-ccfc-4c0c-b6bc-5c232c210c74.mkv...
# Deleted original video scraped/2022/02/16/9334b34a-ccfc-4c0c-b6bc-5c232c210c74.mkv
# Finished scraped/2022/02/16/9334b34a-ccfc-4c0c-b6bc-5c232c210c74.mkv
# Processing scraped/2022/02/01/0da4a5a8-fddd-4e7a-b971-669943750a3f.mkv...
# Deleted original video scraped/2022/02/01/0da4a5a8-fddd-4e7a-b971-669943750a3f.mkv
# Finished scraped/2022/02/01/0da4a5a8-fddd-4e7a-b971-669943750a3f.mkv
# Processing scraped/2022/02/14/7e9776ee-4fe4-4500-b8d6-313135efbcd9.mkv...
# Deleted original video scraped/2022/02/14/7e9776ee-4fe4-4500-b8d6-313135efbcd9.mkv
# Finished scraped/2022/02/14/7e9776ee-4fe4-4500-b8d6-313135efbcd9.mkv
# Processing scraped/2022/02/11/31680e65-8a4c-4d5d-94e7-f2971578f862.mkv...
# Deleted original video scraped/2022/02/11/31680e65-8a4c-4d5d-94e7-f2971578f862.mkv
# Finished scraped/2022/02/11/31680e65-8a4c-4d5d-94e7-f2971578f862.mkv
# Processing scraped/2022/02/02/81360752-ec98-41cd-86f8-c914a1bee5b8.mkv...
# Deleted original video scraped/2022/02/02/81360752-ec98-41cd-86f8-c914a1bee5b8.mkv
# Finished scraped/2022/02/02/81360752-ec98-41cd-86f8-c914a1bee5b8.mkv
# Processing scraped/2022/02/25/5820cb19-31aa-438c-a6df-38f9a9f2f140.mkv...
# Deleted original video scraped/2022/02/25/5820cb19-31aa-438c-a6df-38f9a9f2f140.mkv
# Finished scraped/2022/02/25/5820cb19-31aa-438c-a6df-38f9a9f2f140.mkv
# Processing scraped/2022/02/08/724bb9d2-48a0-4f72-a0fd-ead576ed420e.mkv...
# Deleted original video scraped/2022/02/08/724bb9d2-48a0-4f72-a0fd-ead576ed420e.mkv
# Finished scraped/2022/02/08/724bb9d2-48a0-4f72-a0fd-ead576ed420e.mkv
# Processing scraped/2022/02/04/e762210d-c36f-4d9a-b6ae-d1c7b1c3c0eb.mkv...
# Deleted original video scraped/2022/02/04/e762210d-c36f-4d9a-b6ae-d1c7b1c3c0eb.mkv
# Finished scraped/2022/02/04/e762210d-c36f-4d9a-b6ae-d1c7b1c3c0eb.mkv
# Processing scraped/2022/02/28/16ab67a5-b57b-4f97-b572-0fa6c383816a.mkv as 2 segments...
# Deleted original video scraped/2022/02/28/16ab67a5-b57b-4f97-b572-0fa6c383816a.mkv
# Finished scraped/2022/02/28/16ab67a5-b57b-4f97-b572-0fa6c383816a.mkv
# Processing scraped/2022/02/17/17891c10-5472-4e7c-b663-c705f74c5d19.mkv...
# Deleted original video scraped/2022/02/17/17891c10-5472-4e7c-b663-c705f74c5d19.mkv
# Finished scraped/2022/02/17/17891c10-5472-4e7c-b663-c705f74c5d19.mkv
# Processing scraped/2022/02/07/e583bc97-b0a8-49fc-a63e-4f511d4014c4.mkv...
# Deleted original video scraped/2022/02/07/e583bc97-b0a8-49fc-a63e-4f511d4014c4.mkv
# Finished scraped/2022/02/07/e583bc97-b0a8-49fc-a63e-4f511d4014c4.mkv
# No video found for scraped/2022/08/05/406bc336-f5f0-4e43-86c2-fa1957b33509.json, skipping.
# No video found for scraped/2022/08/22/5b9f3a73-43e3-4924-8833-fe96aa4390fb.json, skipping.
# No video found for scraped/2022/08/29/d24735c7-1ec1-47f0-9511-29be5e0168d4.json, skipping.
# No video found for scraped/2022/08/10/dac80be4-06eb-4edb-840d-b4424aa48a14.json, skipping.
# No video found for scraped/2022/08/03/0b301971-0cd0-456c-8bde-42f5f659d86f.json, skipping.
# No video found for scraped/2022/08/31/e85094dd-5e23-4a4b-9f33-e42cd5bfc299.json, skipping.
# No video found for scraped/2022/08/23/b642e6c5-3e4b-4076-868e-2dd620cb2bf4.json, skipping.
# No video found for scraped/2022/08/12/abb53ad0-2ae4-4d8f-8195-a5359b3f38a8.json, skipping.
# No video found for scraped/2022/08/24/fb84827a-af55-45c3-a99d-f8fefbf9dd81.json, skipping.
# No video found for scraped/2022/08/26/c20cfa6f-fb85-49ae-9693-71be76dc8a3f.json, skipping.
# No video found for scraped/2022/08/09/d7e6a9c3-9c5b-490c-aae2-b55f8dc0f95f.json, skipping.
# No video found for scraped/2022/08/01/9dcdf436-e9a0-48ec-b36d-6e5e42eebace.json, skipping.
# No video found for scraped/2022/08/11/39ac3995-a69d-41fb-b4a1-8d3550b714c1.json, skipping.
# No video found for scraped/2022/08/25/2ad37f52-2a18-4d10-a54a-783f7161f1de.json, skipping.
# No video found for scraped/2022/08/08/b44fc33e-1f26-490e-804f-9243c5376c30.json, skipping.
# No video found for scraped/2022/08/04/ef6425b3-01d7-4d29-81fa-b0793c04c5c1.json, skipping.
# No video found for scraped/2022/08/30/c00a1009-5509-4c60-97c2-ced553167962.json, skipping.
# No video found for scraped/2022/08/17/acf3d4fc-8b31-4662-bc7f-a5fa1cb84c31.json, skipping.
# Processing scraped/2022/04/22/d0700326-c76a-40a0-94fc-0bbf452c5d3c.mkv...
# Deleted original video scraped/2022/04/22/d0700326-c76a-40a0-94fc-0bbf452c5d3c.mkv
# Finished scraped/2022/04/22/d0700326-c76a-40a0-94fc-0bbf452c5d3c.mkv
# Processing scraped/2022/04/29/dca9619b-21b9-4fb4-b06a-45aea81245ae.mkv...
# Deleted original video scraped/2022/04/29/dca9619b-21b9-4fb4-b06a-45aea81245ae.mkv
# Finished scraped/2022/04/29/dca9619b-21b9-4fb4-b06a-45aea81245ae.mkv
# Processing scraped/2022/04/21/693fec81-c28c-43f3-ba4d-f3a5ff4e6b9b.mkv...
# Deleted original video scraped/2022/04/21/693fec81-c28c-43f3-ba4d-f3a5ff4e6b9b.mkv
# Finished scraped/2022/04/21/693fec81-c28c-43f3-ba4d-f3a5ff4e6b9b.mkv
# Processing scraped/2022/04/13/3ffaf7bd-3434-4ee4-8f74-118d3ac760ee.mkv...
# Deleted original video scraped/2022/04/13/3ffaf7bd-3434-4ee4-8f74-118d3ac760ee.mkv
# Finished scraped/2022/04/13/3ffaf7bd-3434-4ee4-8f74-118d3ac760ee.mkv
# Processing scraped/2022/04/18/d1451d83-1791-4888-af31-ef7c57ff311d.mkv...
# Deleted original video scraped/2022/04/18/d1451d83-1791-4888-af31-ef7c57ff311d.mkv
# Finished scraped/2022/04/18/d1451d83-1791-4888-af31-ef7c57ff311d.mkv
# Processing scraped/2022/04/26/4afe2972-7374-4fc9-963c-7f4fd05019d8.mkv...
# Deleted original video scraped/2022/04/26/4afe2972-7374-4fc9-963c-7f4fd05019d8.mkv
# Finished scraped/2022/04/26/4afe2972-7374-4fc9-963c-7f4fd05019d8.mkv
# Processing scraped/2022/04/20/f791d355-f407-4b01-936e-0ac46714253f.mkv...
# Deleted original video scraped/2022/04/20/f791d355-f407-4b01-936e-0ac46714253f.mkv
# Finished scraped/2022/04/20/f791d355-f407-4b01-936e-0ac46714253f.mkv
# Processing scraped/2022/04/01/2d699517-7ad1-402c-9abc-6b60587bf008.mkv as 2 segments...
# Deleted original video scraped/2022/04/01/2d699517-7ad1-402c-9abc-6b60587bf008.mkv
# Finished scraped/2022/04/01/2d699517-7ad1-402c-9abc-6b60587bf008.mkv
# Processing scraped/2022/04/14/c88390fb-89bc-4265-aea1-518fefd8fc07.mkv...
# Deleted original video scraped/2022/04/14/c88390fb-89bc-4265-aea1-518fefd8fc07.mkv
# Finished scraped/2022/04/14/c88390fb-89bc-4265-aea1-518fefd8fc07.mkv
# Processing scraped/2022/04/11/acb8ad5c-9bb3-46f4-9be9-70bf7740ffdb.mkv...
# Deleted original video scraped/2022/04/11/acb8ad5c-9bb3-46f4-9be9-70bf7740ffdb.mkv
# Finished scraped/2022/04/11/acb8ad5c-9bb3-46f4-9be9-70bf7740ffdb.mkv
# Processing scraped/2022/04/27/148ad08e-afa5-4373-ad70-84e73f850b4d.mkv...
# Deleted original video scraped/2022/04/27/148ad08e-afa5-4373-ad70-84e73f850b4d.mkv
# Finished scraped/2022/04/27/148ad08e-afa5-4373-ad70-84e73f850b4d.mkv
# Processing scraped/2022/04/06/0300f92d-a948-44e7-a3a5-007a6b0a0993.mkv...
# Deleted original video scraped/2022/04/06/0300f92d-a948-44e7-a3a5-007a6b0a0993.mkv
# Finished scraped/2022/04/06/0300f92d-a948-44e7-a3a5-007a6b0a0993.mkv
# Processing scraped/2022/04/08/d10aad73-ac94-492d-8a1d-e79a18e457c0.mkv...
# Deleted original video scraped/2022/04/08/d10aad73-ac94-492d-8a1d-e79a18e457c0.mkv
# Finished scraped/2022/04/08/d10aad73-ac94-492d-8a1d-e79a18e457c0.mkv
# Processing scraped/2022/04/28/a6fb909e-4446-4b9d-b298-e6e05c5b4f5e.mkv...
# Deleted original video scraped/2022/04/28/a6fb909e-4446-4b9d-b298-e6e05c5b4f5e.mkv
# Finished scraped/2022/04/28/a6fb909e-4446-4b9d-b298-e6e05c5b4f5e.mkv
# Processing scraped/2022/04/07/38d04013-9085-46c1-bce2-e9b265cae8d0.mkv...
# Deleted original video scraped/2022/04/07/38d04013-9085-46c1-bce2-e9b265cae8d0.mkv
# Finished scraped/2022/04/07/38d04013-9085-46c1-bce2-e9b265cae8d0.mkv
# Processing scraped/2022/04/19/d76581b4-1453-44f6-82e1-233b59a9551d.mkv...
# Deleted original video scraped/2022/04/19/d76581b4-1453-44f6-82e1-233b59a9551d.mkv
# Finished scraped/2022/04/19/d76581b4-1453-44f6-82e1-233b59a9551d.mkv
# No video found for scraped/2022/07/05/aa1f2015-d8f2-42cd-9bcb-30e7b61dfbb5.json, skipping.
# No video found for scraped/2022/07/22/d875dfc9-4e16-41ff-aeb8-74e0f40101f8.json, skipping.
# No video found for scraped/2022/07/21/c395de01-8d47-497f-a8d4-74cbf348b0ed.json, skipping.
# No video found for scraped/2022/07/15/cedb1a4c-0f92-4eb4-bea3-c8ccc479985e.json, skipping.
# No video found for scraped/2022/07/13/89a2d311-f77f-47d8-8b96-026d052bcbd2.json, skipping.
# No video found for scraped/2022/07/18/b7411361-5a1d-4004-8432-a31d719cd6db.json, skipping.
# No video found for scraped/2022/07/12/50c5b002-d084-4dcc-a6e0-e3e655d776fa.json, skipping.
# No video found for scraped/2022/07/26/55fceb45-a8e4-4030-b1c1-0ac33e7bed98.json, skipping.
# No video found for scraped/2022/07/20/e15393aa-4fab-4315-b7f5-c2b9643d9537.json, skipping.
# Processing scraped/2022/07/01/738006a3-fa3c-45d9-bda9-fef44726a7a2.mkv...
# Deleted original video scraped/2022/07/01/738006a3-fa3c-45d9-bda9-fef44726a7a2.mkv
# Finished scraped/2022/07/01/738006a3-fa3c-45d9-bda9-fef44726a7a2.mkv
# No video found for scraped/2022/07/14/5f07ec1b-c309-4bb3-a7dc-fa4ee9448f20.json, skipping.
# No video found for scraped/2022/07/11/e08cf838-a493-4d4c-ae41-f94eb8a42215.json, skipping.
# No video found for scraped/2022/07/27/3efdf963-f111-4367-8fff-3e25f4f7339c.json, skipping.
# No video found for scraped/2022/07/25/8e7da5c9-2e77-49a3-a9ae-4e030eca1643.json, skipping.
# No video found for scraped/2022/07/08/fe046592-71ac-47d1-a449-57925e7d2b0b.json, skipping.
# Processing scraped/2022/07/04/ff040cac-caaf-4925-acc4-27887b1572f6.mkv...
# Deleted original video scraped/2022/07/04/ff040cac-caaf-4925-acc4-27887b1572f6.mkv
# Finished scraped/2022/07/04/ff040cac-caaf-4925-acc4-27887b1572f6.mkv
# No video found for scraped/2022/07/28/52a95a3f-bfdb-4af1-9f07-ca13fe24fba3.json, skipping.
# No video found for scraped/2022/07/07/0c6a90ae-a937-4c9b-a6e7-9160d8a01879.json, skipping.
# No video found for scraped/2022/07/19/b616576a-ebbe-49f9-97db-cedfea840199.json, skipping.
# Processing scraped/2021/05/10/21b433ba-f595-40e9-a1d7-ad3c5939a6d2.mkv as 2 segments...
# Deleted original video scraped/2021/05/10/21b433ba-f595-40e9-a1d7-ad3c5939a6d2.mkv
# Finished scraped/2021/05/10/21b433ba-f595-40e9-a1d7-ad3c5939a6d2.mkv
# Processing scraped/2021/05/31/5a936525-9441-47de-a7e5-b5050b3a640a.mkv as 2 segments...
# Deleted original video scraped/2021/05/31/5a936525-9441-47de-a7e5-b5050b3a640a.mkv
# Finished scraped/2021/05/31/5a936525-9441-47de-a7e5-b5050b3a640a.mkv
# Processing scraped/2021/05/13/8df3d221-d3b0-489c-8f4c-27b17d1897ed.mkv as 2 segments...
# Deleted original video scraped/2021/05/13/8df3d221-d3b0-489c-8f4c-27b17d1897ed.mkv
# Finished scraped/2021/05/13/8df3d221-d3b0-489c-8f4c-27b17d1897ed.mkv
# Processing scraped/2021/05/18/20473e5c-94ad-401c-9ff6-a9669bdd5f8b.mkv as 2 segments...
# Deleted original video scraped/2021/05/18/20473e5c-94ad-401c-9ff6-a9669bdd5f8b.mkv
# Finished scraped/2021/05/18/20473e5c-94ad-401c-9ff6-a9669bdd5f8b.mkv
# Processing scraped/2021/05/12/e20a6f90-732f-4bd5-8e63-37848f187ea3.mkv as 2 segments...
# Deleted original video scraped/2021/05/12/e20a6f90-732f-4bd5-8e63-37848f187ea3.mkv
# Finished scraped/2021/05/12/e20a6f90-732f-4bd5-8e63-37848f187ea3.mkv
# Processing scraped/2021/05/24/bca98dd6-c7e5-412a-8670-67fcc3245d67.mkv as 2 segments...
# Deleted original video scraped/2021/05/24/bca98dd6-c7e5-412a-8670-67fcc3245d67.mkv
# Finished scraped/2021/05/24/bca98dd6-c7e5-412a-8670-67fcc3245d67.mkv
# Processing scraped/2021/05/26/272b57aa-a20e-4dfb-bc3f-0557fcc9ec11.mkv as 2 segments...
# Deleted original video scraped/2021/05/26/272b57aa-a20e-4dfb-bc3f-0557fcc9ec11.mkv
# Finished scraped/2021/05/26/272b57aa-a20e-4dfb-bc3f-0557fcc9ec11.mkv
# Processing scraped/2021/05/20/fe23b9b1-ca3a-4aae-a24a-085934fc1f5c.mkv as 2 segments...
# Deleted original video scraped/2021/05/20/fe23b9b1-ca3a-4aae-a24a-085934fc1f5c.mkv
# Finished scraped/2021/05/20/fe23b9b1-ca3a-4aae-a24a-085934fc1f5c.mkv
# Processing scraped/2021/05/14/adf7d7b0-8412-4be9-a33b-2579d2fbd749.mkv as 2 segments...
# Deleted original video scraped/2021/05/14/adf7d7b0-8412-4be9-a33b-2579d2fbd749.mkv
# Finished scraped/2021/05/14/adf7d7b0-8412-4be9-a33b-2579d2fbd749.mkv
# Processing scraped/2021/05/11/46733cb8-d4b6-4506-ae21-e28ea8f11733.mkv as 2 segments...
# Deleted original video scraped/2021/05/11/46733cb8-d4b6-4506-ae21-e28ea8f11733.mkv
# Finished scraped/2021/05/11/46733cb8-d4b6-4506-ae21-e28ea8f11733.mkv
# Processing scraped/2021/05/27/23c35833-b28a-43bb-b5bc-5d249b4941be.mkv as 2 segments...
# Deleted original video scraped/2021/05/27/23c35833-b28a-43bb-b5bc-5d249b4941be.mkv
# Finished scraped/2021/05/27/23c35833-b28a-43bb-b5bc-5d249b4941be.mkv
# Processing scraped/2021/05/06/9dfd3f39-1bbb-459e-bc61-127e796bdf64.mkv as 2 segments...
# Deleted original video scraped/2021/05/06/9dfd3f39-1bbb-459e-bc61-127e796bdf64.mkv
# Finished scraped/2021/05/06/9dfd3f39-1bbb-459e-bc61-127e796bdf64.mkv
# Processing scraped/2021/05/25/19d268b5-7e2a-4ba9-97d1-8f3cea3b0516.mkv as 2 segments...
# Deleted original video scraped/2021/05/25/19d268b5-7e2a-4ba9-97d1-8f3cea3b0516.mkv
# Finished scraped/2021/05/25/19d268b5-7e2a-4ba9-97d1-8f3cea3b0516.mkv
# Processing scraped/2021/05/04/a41c384a-3a5f-4144-92ff-8b846724ceaf.mkv as 2 segments...
# Deleted original video scraped/2021/05/04/a41c384a-3a5f-4144-92ff-8b846724ceaf.mkv
# Finished scraped/2021/05/04/a41c384a-3a5f-4144-92ff-8b846724ceaf.mkv
# Processing scraped/2021/05/28/d5b75d20-23a7-4395-8092-804a275c9090.mkv as 2 segments...
# Deleted original video scraped/2021/05/28/d5b75d20-23a7-4395-8092-804a275c9090.mkv
# Finished scraped/2021/05/28/d5b75d20-23a7-4395-8092-804a275c9090.mkv
# Processing scraped/2021/05/19/9dfbf246-b192-4ee6-bc4e-dd7484abe7b4.mkv as 2 segments...
# Deleted original video scraped/2021/05/19/9dfbf246-b192-4ee6-bc4e-dd7484abe7b4.mkv
# Finished scraped/2021/05/19/9dfbf246-b192-4ee6-bc4e-dd7484abe7b4.mkv
# Processing scraped/2021/10/22/b26c6366-457e-4d80-8112-ca2b919fe2aa.mkv...
# Deleted original video scraped/2021/10/22/b26c6366-457e-4d80-8112-ca2b919fe2aa.mkv
# Finished scraped/2021/10/22/b26c6366-457e-4d80-8112-ca2b919fe2aa.mkv
# Processing scraped/2021/10/13/a3acc33b-bb0a-4904-a534-66e23a06ecc5.mkv...
# Deleted original video scraped/2021/10/13/a3acc33b-bb0a-4904-a534-66e23a06ecc5.mkv
# Finished scraped/2021/10/13/a3acc33b-bb0a-4904-a534-66e23a06ecc5.mkv
# Processing scraped/2021/10/12/38bb960f-3ac8-4f9e-9f7e-4e6e4a3b3d01.mkv...
# Deleted original video scraped/2021/10/12/38bb960f-3ac8-4f9e-9f7e-4e6e4a3b3d01.mkv
# Finished scraped/2021/10/12/38bb960f-3ac8-4f9e-9f7e-4e6e4a3b3d01.mkv
# Processing scraped/2021/10/26/40e713be-086c-4830-9fec-54ebc82c8f14.mkv...
# Deleted original video scraped/2021/10/26/40e713be-086c-4830-9fec-54ebc82c8f14.mkv
# Finished scraped/2021/10/26/40e713be-086c-4830-9fec-54ebc82c8f14.mkv
# Processing scraped/2021/10/20/8e11fb64-19e7-42e1-ae26-71221321f226.mkv...
# Deleted original video scraped/2021/10/20/8e11fb64-19e7-42e1-ae26-71221321f226.mkv
# Finished scraped/2021/10/20/8e11fb64-19e7-42e1-ae26-71221321f226.mkv
# Processing scraped/2021/10/14/95b0e9a1-efb4-4a6a-b5ce-4dc75f202f44.mkv...
# Deleted original video scraped/2021/10/14/95b0e9a1-efb4-4a6a-b5ce-4dc75f202f44.mkv
# Finished scraped/2021/10/14/95b0e9a1-efb4-4a6a-b5ce-4dc75f202f44.mkv
# Processing scraped/2021/10/11/4cd61517-74fe-4703-9625-c72e27435de6.mkv...
# Deleted original video scraped/2021/10/11/4cd61517-74fe-4703-9625-c72e27435de6.mkv
# Finished scraped/2021/10/11/4cd61517-74fe-4703-9625-c72e27435de6.mkv
# Processing scraped/2021/10/27/8635362c-028c-450d-9816-50fd10476d15.mkv...
# Deleted original video scraped/2021/10/27/8635362c-028c-450d-9816-50fd10476d15.mkv
# Finished scraped/2021/10/27/8635362c-028c-450d-9816-50fd10476d15.mkv
# Processing scraped/2021/10/04/9e0e891e-09fb-41ac-9f2c-4a633b70804b.mkv...
# Deleted original video scraped/2021/10/04/9e0e891e-09fb-41ac-9f2c-4a633b70804b.mkv
# Finished scraped/2021/10/04/9e0e891e-09fb-41ac-9f2c-4a633b70804b.mkv
# Processing scraped/2021/10/07/bf603743-1775-4208-b648-e9ed32eb8bae.mkv...
# Deleted original video scraped/2021/10/07/bf603743-1775-4208-b648-e9ed32eb8bae.mkv
# Finished scraped/2021/10/07/bf603743-1775-4208-b648-e9ed32eb8bae.mkv
# Processing scraped/2021/10/19/b9e82483-a6d2-4c70-ae59-f934e0fe8e55.mkv...
# Deleted original video scraped/2021/10/19/b9e82483-a6d2-4c70-ae59-f934e0fe8e55.mkv
# Finished scraped/2021/10/19/b9e82483-a6d2-4c70-ae59-f934e0fe8e55.mkv
# Processing scraped/2021/03/05/39972d2b-cbd1-4f5f-801c-83e1d5f5b4db.mkv as 2 segments...
# Deleted original video scraped/2021/03/05/39972d2b-cbd1-4f5f-801c-83e1d5f5b4db.mkv
# Finished scraped/2021/03/05/39972d2b-cbd1-4f5f-801c-83e1d5f5b4db.mkv
# Processing scraped/2021/03/22/977b1f9c-ae45-40d1-aa3c-807f25e66f41.mkv as 2 segments...
# Deleted original video scraped/2021/03/22/977b1f9c-ae45-40d1-aa3c-807f25e66f41.mkv
# Finished scraped/2021/03/22/977b1f9c-ae45-40d1-aa3c-807f25e66f41.mkv
# Processing scraped/2021/03/29/aa925aaa-9a0e-4b28-b899-72f724f55371.mkv as 2 segments...
# Deleted original video scraped/2021/03/29/aa925aaa-9a0e-4b28-b899-72f724f55371.mkv
# Finished scraped/2021/03/29/aa925aaa-9a0e-4b28-b899-72f724f55371.mkv
# Processing scraped/2021/03/10/b29d10d8-b99c-4e02-af11-63646a299dae.mkv...
# Deleted original video scraped/2021/03/10/b29d10d8-b99c-4e02-af11-63646a299dae.mkv
# Finished scraped/2021/03/10/b29d10d8-b99c-4e02-af11-63646a299dae.mkv
# Processing scraped/2021/03/03/688412ea-8786-4088-b55a-01f933e47793.mkv as 2 segments...
# Deleted original video scraped/2021/03/03/688412ea-8786-4088-b55a-01f933e47793.mkv
# Finished scraped/2021/03/03/688412ea-8786-4088-b55a-01f933e47793.mkv
# Processing scraped/2021/03/15/721ba36a-c37c-4c46-9acf-549ece6dea56.mkv as 2 segments...
# Deleted original video scraped/2021/03/15/721ba36a-c37c-4c46-9acf-549ece6dea56.mkv
# Finished scraped/2021/03/15/721ba36a-c37c-4c46-9acf-549ece6dea56.mkv
# Processing scraped/2021/03/31/67aec431-190c-4314-be48-f0ef1b9aac76.mkv as 2 segments...
# Deleted original video scraped/2021/03/31/67aec431-190c-4314-be48-f0ef1b9aac76.mkv
# Finished scraped/2021/03/31/67aec431-190c-4314-be48-f0ef1b9aac76.mkv
# Processing scraped/2021/03/23/1c91ea95-d8d6-438b-89fe-89a21177f16c.mkv as 2 segments...
# Deleted original video scraped/2021/03/23/1c91ea95-d8d6-438b-89fe-89a21177f16c.mkv
# Finished scraped/2021/03/23/1c91ea95-d8d6-438b-89fe-89a21177f16c.mkv
# Processing scraped/2021/03/18/eada8597-c6b3-47ec-92b1-ee837d598c66.mkv as 2 segments...
# Deleted original video scraped/2021/03/18/eada8597-c6b3-47ec-92b1-ee837d598c66.mkv
# Finished scraped/2021/03/18/eada8597-c6b3-47ec-92b1-ee837d598c66.mkv
# Processing scraped/2021/03/12/3ce3d021-3cb2-4609-bb6f-8aa392291109.mkv as 2 segments...
# Deleted original video scraped/2021/03/12/3ce3d021-3cb2-4609-bb6f-8aa392291109.mkv
# Finished scraped/2021/03/12/3ce3d021-3cb2-4609-bb6f-8aa392291109.mkv
# Processing scraped/2021/03/24/8546a451-b10d-489b-a1aa-f124271edbd2.mkv as 2 segments...
# Deleted original video scraped/2021/03/24/8546a451-b10d-489b-a1aa-f124271edbd2.mkv
# Finished scraped/2021/03/24/8546a451-b10d-489b-a1aa-f124271edbd2.mkv
# Processing scraped/2021/03/16/e19db1f3-89b9-4585-af73-9c4718fa19c5.mkv as 2 segments...
# Deleted original video scraped/2021/03/16/e19db1f3-89b9-4585-af73-9c4718fa19c5.mkv
# Finished scraped/2021/03/16/e19db1f3-89b9-4585-af73-9c4718fa19c5.mkv
# Processing scraped/2021/03/01/d485f09d-dc2f-47ab-b1ef-5bf156f7ba94.mkv as 2 segments...
# Deleted original video scraped/2021/03/01/d485f09d-dc2f-47ab-b1ef-5bf156f7ba94.mkv
# Finished scraped/2021/03/01/d485f09d-dc2f-47ab-b1ef-5bf156f7ba94.mkv
# Processing scraped/2021/03/11/c5470d67-b194-4a3a-9454-7f0465466050.mkv as 2 segments...
# Deleted original video scraped/2021/03/11/c5470d67-b194-4a3a-9454-7f0465466050.mkv
# Finished scraped/2021/03/11/c5470d67-b194-4a3a-9454-7f0465466050.mkv
# Processing scraped/2021/03/02/bc8a1bbf-c288-4cbd-ac4a-39215fa6e648.mkv as 2 segments...
# Deleted original video scraped/2021/03/02/bc8a1bbf-c288-4cbd-ac4a-39215fa6e648.mkv
# Finished scraped/2021/03/02/bc8a1bbf-c288-4cbd-ac4a-39215fa6e648.mkv
# Processing scraped/2021/03/04/47ecbe64-3a18-4edd-a108-38e5b4960e06.mkv as 2 segments...
# Deleted original video scraped/2021/03/04/47ecbe64-3a18-4edd-a108-38e5b4960e06.mkv
# Finished scraped/2021/03/04/47ecbe64-3a18-4edd-a108-38e5b4960e06.mkv
# Processing scraped/2021/03/30/a65e4594-bfba-482c-9466-9eb0f0a1f6c3.mkv as 2 segments...
# Deleted original video scraped/2021/03/30/a65e4594-bfba-482c-9466-9eb0f0a1f6c3.mkv
# Finished scraped/2021/03/30/a65e4594-bfba-482c-9466-9eb0f0a1f6c3.mkv
# Processing scraped/2021/03/17/d2f2546b-adbf-4a92-8953-ec031621eefd.mkv as 2 segments...
# Deleted original video scraped/2021/03/17/d2f2546b-adbf-4a92-8953-ec031621eefd.mkv
# Finished scraped/2021/03/17/d2f2546b-adbf-4a92-8953-ec031621eefd.mkv
# Processing scraped/2021/03/19/a9ca1518-a37f-4a9d-bbe5-fe2fd04a572b.mkv as 2 segments...
# Deleted original video scraped/2021/03/19/a9ca1518-a37f-4a9d-bbe5-fe2fd04a572b.mkv
# Finished scraped/2021/03/19/a9ca1518-a37f-4a9d-bbe5-fe2fd04a572b.mkv
# Processing scraped/2021/12/29/366599f0-ae5e-4090-afd5-a1bc9a470ae3.mkv...
# Deleted original video scraped/2021/12/29/366599f0-ae5e-4090-afd5-a1bc9a470ae3.mkv
# Finished scraped/2021/12/29/366599f0-ae5e-4090-afd5-a1bc9a470ae3.mkv
# Processing scraped/2021/12/10/bf322cbd-7d28-4683-865d-62d5fc97e7ae.mkv...
# Deleted original video scraped/2021/12/10/bf322cbd-7d28-4683-865d-62d5fc97e7ae.mkv
# Finished scraped/2021/12/10/bf322cbd-7d28-4683-865d-62d5fc97e7ae.mkv
# Processing scraped/2021/12/21/d679d802-9dc1-4381-991d-1b65d8df0849.mkv...
# Deleted original video scraped/2021/12/21/d679d802-9dc1-4381-991d-1b65d8df0849.mkv
# Finished scraped/2021/12/21/d679d802-9dc1-4381-991d-1b65d8df0849.mkv
# Processing scraped/2021/12/31/787f0d06-a485-4a1e-bef6-f806f8ad73bc.mkv...
# Deleted original video scraped/2021/12/31/787f0d06-a485-4a1e-bef6-f806f8ad73bc.mkv
# Finished scraped/2021/12/31/787f0d06-a485-4a1e-bef6-f806f8ad73bc.mkv
# Processing scraped/2021/12/23/58393d99-c363-4f58-bf2a-dcf074469a3c.mkv...
# Deleted original video scraped/2021/12/23/58393d99-c363-4f58-bf2a-dcf074469a3c.mkv
# Finished scraped/2021/12/23/58393d99-c363-4f58-bf2a-dcf074469a3c.mkv
# Processing scraped/2021/12/13/52ac7bd7-7b21-4fb1-aa3e-af90782a944e.mkv...
# Deleted original video scraped/2021/12/13/52ac7bd7-7b21-4fb1-aa3e-af90782a944e.mkv
# Finished scraped/2021/12/13/52ac7bd7-7b21-4fb1-aa3e-af90782a944e.mkv
# Processing scraped/2021/12/24/2a7cf389-22e5-471b-ae0e-6ab3b0b8915f.mkv...
# Deleted original video scraped/2021/12/24/2a7cf389-22e5-471b-ae0e-6ab3b0b8915f.mkv
# Finished scraped/2021/12/24/2a7cf389-22e5-471b-ae0e-6ab3b0b8915f.mkv
# Processing scraped/2021/12/14/cfd58d07-5b90-4601-8682-6c225dd7b4be.mkv as 2 segments...
# Deleted original video scraped/2021/12/14/cfd58d07-5b90-4601-8682-6c225dd7b4be.mkv
# Finished scraped/2021/12/14/cfd58d07-5b90-4601-8682-6c225dd7b4be.mkv
# Processing scraped/2021/12/27/24071b1a-f06e-48ab-ae59-f8658d4648be.mkv...
# Deleted original video scraped/2021/12/27/24071b1a-f06e-48ab-ae59-f8658d4648be.mkv
# Finished scraped/2021/12/27/24071b1a-f06e-48ab-ae59-f8658d4648be.mkv
# Processing scraped/2021/12/28/ed98a927-3251-4d1d-9974-7cb196234266.mkv...
# Deleted original video scraped/2021/12/28/ed98a927-3251-4d1d-9974-7cb196234266.mkv
# Finished scraped/2021/12/28/ed98a927-3251-4d1d-9974-7cb196234266.mkv
# Processing scraped/2021/12/30/e4f49da8-ccb6-4a19-a680-2c7f3d02f5fc.mkv...
# ...
# No video found for scraped/2024/03/23/62435827-2.json, skipping.
# No video found for scraped/2024/03/13/62433248-2.json, skipping.
# No video found for scraped/2024/03/13/62433238-2.json, skipping.
# No video found for scraped/2024/03/18/62434373-2.json, skipping.
# No video found for scraped/2024/03/12/62432932-2.json, skipping.
# No video found for scraped/2024/03/24/62435948-2.json, skipping.
# No video found for scraped/2024/03/26/62436565-2.json, skipping.
# No video found for scraped/2024/03/20/62435044-2.json, skipping.
# No video found for scraped/2024/03/09/62432166-2.json, skipping.
# No video found for scraped/2024/03/16/62433949-2.json, skipping.
# No video found for scraped/2024/03/01/62429788-2.json, skipping.
# No video found for scraped/2024/03/11/62432693-2.json, skipping.
# No video found for scraped/2024/03/27/62436808-2.json, skipping.
# No video found for scraped/2024/03/06/62431204-2.json, skipping.
# No video found for scraped/2024/03/25/62436237-2.json, skipping.
# No video found for scraped/2024/03/08/62431740-2.json, skipping.
# No video found for scraped/2024/03/08/62431849-2.json, skipping.
# No video found for scraped/2024/03/04/62430559-2.json, skipping.
# No video found for scraped/2024/03/04/62430493-2.json, skipping.
# No video found for scraped/2024/03/28/62437137-2.json, skipping.
# No video found for scraped/2024/03/19/62434712-2.json, skipping.
# No video found for scraped/2024/12/22/62507025-2.json, skipping.
# No video found for scraped/2024/12/29/62508388-2.json, skipping.
# No video found for scraped/2024/12/10/62504358-2.json, skipping.
# No video found for scraped/2024/12/21/62506865-2.json, skipping.
# No video found for scraped/2024/12/15/62505464-2.json, skipping.
# No video found for scraped/2024/12/31/62508749-2.json, skipping.
# No video found for scraped/2024/12/23/62507239-2.json, skipping.
# No video found for scraped/2024/12/12/62504859-2.json, skipping.
# No video found for scraped/2024/12/24/62507572-2.json, skipping.
# No video found for scraped/2024/12/26/62507877-2.json, skipping.
# No video found for scraped/2024/12/20/62506602-2.json, skipping.
# No video found for scraped/2024/12/09/62504084-2.json, skipping.
# No video found for scraped/2024/12/16/62505613-2.json, skipping.
# No video found for scraped/2024/12/01/62502226-2.json, skipping.
# No video found for scraped/2024/12/14/62505349-2.json, skipping.
# No video found for scraped/2024/12/11/62504640-2.json, skipping.
# No video found for scraped/2024/12/27/62508038-2.json, skipping.
# No video found for scraped/2024/12/06/62503440-2.json, skipping.
# No video found for scraped/2024/12/02/62502472-2.json, skipping.
# No video found for scraped/2024/12/08/62503970-2.json, skipping.
# No video found for scraped/2024/12/08/62503914-2.json, skipping.
# No video found for scraped/2024/12/28/62508221-2.json, skipping.
# No video found for scraped/2024/12/30/62508521-2.json, skipping.
# No video found for scraped/2024/12/17/62505873-2.json, skipping.
# No video found for scraped/2024/12/07/62503706-2.json, skipping.
# No video found for scraped/2024/12/19/62506323-2.json, skipping.
# No video found for scraped/2024/09/05/62480825-2.json, skipping.
# No video found for scraped/2024/09/29/62486512-2.json, skipping.
# No video found for scraped/2024/09/10/62481867-2.json, skipping.
# No video found for scraped/2024/09/21/62484591-2.json, skipping.
# No video found for scraped/2024/09/03/62480267-2.json, skipping.
# No video found for scraped/2024/09/23/62484890-2.json, skipping.
# No video found for scraped/2024/09/13/62482634-2.json, skipping.
# No video found for scraped/2024/09/18/62483785-2.json, skipping.
# No video found for scraped/2024/09/12/62482413-2.json, skipping.
# No video found for scraped/2024/09/24/62485182-2.json, skipping.
# No video found for scraped/2024/09/20/62484395-2.json, skipping.
# No video found for scraped/2024/09/09/62481594-2.json, skipping.
# No video found for scraped/2024/09/16/62483268-2.json, skipping.
# No video found for scraped/2024/09/01/62479651-2.json, skipping.
# No video found for scraped/2024/09/14/62482851-2.json, skipping.
# No video found for scraped/2024/09/11/62482212-2.json, skipping.
# No video found for scraped/2024/09/27/62486047-2.json, skipping.
# No video found for scraped/2024/09/06/62481106-2.json, skipping.
# No video found for scraped/2024/09/02/62480041-2.json, skipping.
# No video found for scraped/2024/09/02/62479977-2.json, skipping.
# No video found for scraped/2024/09/25/62485450-2.json, skipping.
# No video found for scraped/2024/09/08/62481411-2.json, skipping.
# No video found for scraped/2024/09/04/62480536-2.json, skipping.
# No video found for scraped/2024/09/28/62486293-2.json, skipping.
# No video found for scraped/2024/09/30/62486793-2.json, skipping.
# No video found for scraped/2024/09/19/62484056-2.json, skipping.
# No video found for scraped/2024/01/05/cb0d5dba-a0f1-49a2-b7ff-76c039eafa15.json, skipping.
# No video found for scraped/2024/01/22/ca499ae1-1609-40d6-958e-f20835aaa240.json, skipping.
# No video found for scraped/2024/01/29/773aba0c-5f64-4575-aa89-8b31dfcad39b.json, skipping.
# No video found for scraped/2024/01/03/5ce770a1-520b-4554-a810-d2f8d227b30c.json, skipping.
# No video found for scraped/2024/01/15/4ba43846-7167-413e-b6b3-ff280c7c55d6.json, skipping.
# No video found for scraped/2024/01/31/b2a58e29-5648-44bd-b360-14989c619ba8.json, skipping.
# No video found for scraped/2024/01/23/d889c61a-f5a6-4881-b16d-3e4eb0283553.json, skipping.
# No video found for scraped/2024/01/18/54506141-a6bd-4f50-989f-71b741447845.json, skipping.
# No video found for scraped/2024/01/12/7ea0822c-c756-40f7-9f53-bb886059c271.json, skipping.
# No video found for scraped/2024/01/24/106e4953-aee5-4838-b586-be31291ded17.json, skipping.
# No video found for scraped/2024/01/26/09e2c65f-8ffe-419c-a654-8f230e036cca.json, skipping.
# No video found for scraped/2024/01/09/f5721de1-bdfc-44f3-bc8a-4863c47adeed.json, skipping.
# No video found for scraped/2024/01/16/1fceea7d-7ab9-43f0-ae62-4d667e068e59.json, skipping.
# No video found for scraped/2024/01/11/8d29c726-57ce-4109-bdd5-35887af0f4d3.json, skipping.
# No video found for scraped/2024/01/25/5b2693fe-f55b-4b47-b5ef-b7d764d464b7.json, skipping.
# No video found for scraped/2024/01/04/e50b51ea-d93b-4dd7-b2d6-1d26429d49e0.json, skipping.
# No video found for scraped/2024/01/30/a746740f-429d-4d69-a593-c7e011f7daf7.json, skipping.
# No video found for scraped/2024/01/17/9bd86bf9-b78a-4c32-8ab8-67e4c74980ee.json, skipping.
# No video found for scraped/2024/01/19/2cc7dfce-d1bd-4051-b2bf-6eba48cbb714.json, skipping.
# No video found for scraped/2024/11/05/62496288-2.json, skipping.
# No video found for scraped/2024/11/22/62500086-2.json, skipping.
# No video found for scraped/2024/11/29/62501817-2.json, skipping.
# No video found for scraped/2024/11/21/62499867-2.json, skipping.
# No video found for scraped/2024/11/15/62498604-2.json, skipping.
# No video found for scraped/2024/11/23/62500458-2.json, skipping.
# No video found for scraped/2024/11/13/62498249-2.json, skipping.
# No video found for scraped/2024/11/18/62499086-2.json, skipping.
# No video found for scraped/2024/11/12/62498033-2.json, skipping.
# No video found for scraped/2024/11/24/62500583-2.json, skipping.
# No video found for scraped/2024/11/20/62499552-2.json, skipping.
# No video found for scraped/2024/11/01/62495390-2.json, skipping.
# No video found for scraped/2024/11/14/62498330-2.json, skipping.
# No video found for scraped/2024/11/11/62497741-2.json, skipping.
# No video found for scraped/2024/11/27/62501358-2.json, skipping.
# No video found for scraped/2024/11/06/62496467-2.json, skipping.
# No video found for scraped/2024/11/02/62495572-2.json, skipping.
# No video found for scraped/2024/11/25/62500824-2.json, skipping.
# No video found for scraped/2024/11/08/62496940-2.json, skipping.
# No video found for scraped/2024/11/04/62496043-2.json, skipping.
# No video found for scraped/2024/11/28/62501603-2.json, skipping.
# No video found for scraped/2024/11/30/62501999-2.json, skipping.
# No video found for scraped/2024/11/17/62498891-2.json, skipping.
# No video found for scraped/2024/11/07/62496705-2.json, skipping.
# No video found for scraped/2024/11/19/62499407-2.json, skipping.
# No video found for scraped/2024/06/05/62454762-2.json, skipping.
# No video found for scraped/2024/06/29/62462725-2.json, skipping.
# No video found for scraped/2024/06/10/62456181-2.json, skipping.
# No video found for scraped/2024/06/21/62460055-2.json, skipping.
# No video found for scraped/2024/06/03/62454197-2.json, skipping.
# No video found for scraped/2024/06/15/62457559-2.json, skipping.
# No video found for scraped/2024/06/23/62460763-2.json, skipping.
# No video found for scraped/2024/06/13/62457027-2.json, skipping.
# No video found for scraped/2024/06/18/62458653-2.json, skipping.
# No video found for scraped/2024/06/12/62456781-2.json, skipping.
# No video found for scraped/2024/06/24/62460992-2.json, skipping.
# No video found for scraped/2024/06/26/62461840-2.json, skipping.
# No video found for scraped/2024/06/20/62459612-2.json, skipping.
# No video found for scraped/2024/06/09/62455878-2.json, skipping.
# No video found for scraped/2024/06/14/62457294-2.json, skipping.
# No video found for scraped/2024/06/11/62456468-2.json, skipping.
# No video found for scraped/2024/06/27/62462185-2.json, skipping.
# No video found for scraped/2024/06/06/62455037-2.json, skipping.
# No video found for scraped/2024/06/02/62453958-2.json, skipping.
# No video found for scraped/2024/06/25/62461457-2.json, skipping.
# No video found for scraped/2024/06/08/62455565-2.json, skipping.
# No video found for scraped/2024/06/04/62454509-2.json, skipping.
# No video found for scraped/2024/06/28/62462544-2.json, skipping.
# No video found for scraped/2024/06/30/62462925-2.json, skipping.
# No video found for scraped/2024/06/17/62457914-2.json, skipping.
# No video found for scraped/2024/06/17/62458081-2.json, skipping.
# No video found for scraped/2024/06/07/62455365-2.json, skipping.
# No video found for scraped/2024/06/19/62459026-2.json, skipping.
# No video found for scraped/2024/02/05/25b333d6-e818-41c1-93a2-ecfc9173e174.json, skipping.
# No video found for scraped/2024/02/29/b14373a7-3aa1-4c66-9bf1-b51ac5e59aa4.json, skipping.
# No video found for scraped/2024/02/01/2c2c24a3-2bb4-46d2-957d-b0226a5f0331.json, skipping.
# No video found for scraped/2024/02/06/85e1992a-118a-43b8-b07c-9e2862462eb1.json, skipping.
# No video found for scraped/2024/02/02/ecab6bff-ad75-4d27-a367-7c2024632344.json, skipping.
# No video found for scraped/2024/08/05/62472542-2.json, skipping.
# No video found for scraped/2024/08/22/62477132-2.json, skipping.
# No video found for scraped/2024/08/29/62478808-2.json, skipping.
# No video found for scraped/2024/08/10/62474053-2.json, skipping.
# No video found for scraped/2024/08/21/62476918-2.json, skipping.
# No video found for scraped/2024/08/03/62472014-2.json, skipping.
# No video found for scraped/2024/08/15/62475509-2.json, skipping.
# No video found for scraped/2024/08/31/62479406-2.json, skipping.
# No video found for scraped/2024/08/23/62477382-2.json, skipping.
# No video found for scraped/2024/08/13/62474915-2.json, skipping.
# No video found for scraped/2024/08/18/62476204-2.json, skipping.
# No video found for scraped/2024/08/12/62474457-2.json, skipping.
# No video found for scraped/2024/08/12/62474436-2.json, skipping.
# No video found for scraped/2024/08/24/62477537-2.json, skipping.
# No video found for scraped/2024/08/26/62477904-2.json, skipping.
# No video found for scraped/2024/08/20/62476695-2.json, skipping.
# No video found for scraped/2024/08/09/62473879-2.json, skipping.
# No video found for scraped/2024/08/16/62475760-2.json, skipping.
# No video found for scraped/2024/08/01/62471482-2.json, skipping.
# No video found for scraped/2024/08/14/62475277-2.json, skipping.
# No video found for scraped/2024/08/27/62478185-2.json, skipping.
# No video found for scraped/2024/08/06/62472882-2.json, skipping.
# No video found for scraped/2024/08/02/62471776-2.json, skipping.
# No video found for scraped/2024/08/25/62477665-2.json, skipping.
# No video found for scraped/2024/08/08/62473492-2.json, skipping.
# No video found for scraped/2024/08/04/62472192-2.json, skipping.
# No video found for scraped/2024/08/28/62478467-2.json, skipping.
# No video found for scraped/2024/08/30/62479144-2.json, skipping.
# No video found for scraped/2024/08/17/62475983-2.json, skipping.
# No video found for scraped/2024/08/07/62473202-2.json, skipping.
# No video found for scraped/2024/08/19/62476362-2.json, skipping.
# No video found for scraped/2024/04/05/62439169-2.json, skipping.
# No video found for scraped/2024/04/29/62445454-2.json, skipping.
# No video found for scraped/2024/04/10/62440429-2.json, skipping.
# No video found for scraped/2024/04/21/62443452-2.json, skipping.
# No video found for scraped/2024/04/03/62438730-2.json, skipping.
# No video found for scraped/2024/04/15/62441946-2.json, skipping.
# No video found for scraped/2024/04/15/62441961-2.json, skipping.
# No video found for scraped/2024/04/15/62441953-2.json, skipping.
# No video found for scraped/2024/04/23/62443892-2.json, skipping.
# No video found for scraped/2024/04/18/62442816-2.json, skipping.
# No video found for scraped/2024/04/12/62441105-2.json, skipping.
# No video found for scraped/2024/04/24/62444152-2.json, skipping.
# No video found for scraped/2024/04/26/62444699-2.json, skipping.
# No video found for scraped/2024/04/20/62443305-2.json, skipping.
# No video found for scraped/2024/04/09/62440091-2.json, skipping.
# No video found for scraped/2024/04/16/62442228-2.json, skipping.
# No video found for scraped/2024/04/01/62438025-2.json, skipping.
# No video found for scraped/2024/04/14/62441729-2.json, skipping.
# No video found for scraped/2024/04/11/62440830-2.json, skipping.
# No video found for scraped/2024/04/27/62444942-2.json, skipping.
# No video found for scraped/2024/04/27/62445049-2.json, skipping.
# No video found for scraped/2024/04/02/62438283-2.json, skipping.
# No video found for scraped/2024/04/25/62444492-2.json, skipping.
# No video found for scraped/2024/04/08/62439791-2.json, skipping.
# No video found for scraped/2024/04/04/62438927-2.json, skipping.
# No video found for scraped/2024/04/28/62445137-2.json, skipping.
# No video found for scraped/2024/04/30/62445735-2.json, skipping.
# No video found for scraped/2024/04/17/62442516-2.json, skipping.
# No video found for scraped/2024/04/19/62443062-2.json, skipping.
# No video found for scraped/2024/07/05/62464586-2.json, skipping.
# No video found for scraped/2024/07/22/62468960-2.json, skipping.
# No video found for scraped/2024/07/22/62468934-2.json, skipping.
# No video found for scraped/2024/07/29/62470670-2.json, skipping.
# No video found for scraped/2024/07/21/62468780-2.json, skipping.
# No video found for scraped/2024/07/03/62464096-2.json, skipping.
# No video found for scraped/2024/07/15/62467243-2.json, skipping.
# No video found for scraped/2024/07/31/62471220-2.json, skipping.
# No video found for scraped/2024/07/23/62469181-2.json, skipping.
# No video found for scraped/2024/07/13/62466696-2.json, skipping.
# No video found for scraped/2024/07/18/62468186-2.json, skipping.
# No video found for scraped/2024/07/12/62466506-2.json, skipping.
# No video found for scraped/2024/07/24/62469443-2.json, skipping.
# No video found for scraped/2024/07/26/62470004-2.json, skipping.
# No video found for scraped/2024/07/09/62465565-2.json, skipping.
# No video found for scraped/2024/07/16/62467571-2.json, skipping.
# No video found for scraped/2024/07/01/62463145-2.json, skipping.
# No video found for scraped/2024/07/14/62466891-2.json, skipping.
# No video found for scraped/2024/07/11/62466236-2.json, skipping.
# No video found for scraped/2024/07/02/62463693-2.json, skipping.
# No video found for scraped/2024/07/25/62469701-2.json, skipping.
# No video found for scraped/2024/07/08/62465297-2.json, skipping.
# No video found for scraped/2024/07/04/62464372-2.json, skipping.
# No video found for scraped/2024/07/28/62470408-2.json, skipping.
# No video found for scraped/2024/07/30/62471008-2.json, skipping.
# No video found for scraped/2024/07/17/62467883-2.json, skipping.
